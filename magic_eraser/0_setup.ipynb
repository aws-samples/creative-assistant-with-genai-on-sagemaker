# %% [markdown]
# ## Setup for Magic Eraser Models
# ---
# In this notebook, you are going to run a defined setup process for our magic eraser solution. Due to the size of the models, some of the step may take some time to complete. The entire notebook should finish within 1 hour. At the end of the notebook run, we should have a instended inference container in Elastic Container Registry (ECR) ready to host our models using SageMaker Endpoint (MME).
#
# SageMaker MME is a service provided by Amazon SageMaker that allows multiple machine learning models to be hosted on a single endpoint. This means that multiple models can be deployed and managed together, making it easier to scale and maintain machine learning applications. With a multi-model endpoint, different models can be selected based on specific needs, allowing for more flexibility and efficiency. It also enables different types of models to be combined, such as computer vision and natural language processing models, to create more comprehensive applications.
#
# Here is a high level breakdown of the setup steps:
#
# 1. Downloading pre-trained models
# 2. Package conda environment for additional model dependencies
# 3. Extend SageMaker managed Triton container with model checkpoints and conda packs pre-loaded
# 4. Push the container to AWS Elastic Container Registry (ECR)
#
# ---
#
# This notebook will locally build a custom docker image. **It is recommended to run this example outside of SageMaker Studio**

# %%
# !pip install -Uq nvidia-pyindex 
# !pip install -Uq sagemaker
# !pip install -Uq gradio

# %% [markdown]
# ### Setup

# %%
import sagemaker
import boto3

import tarfile
import os

sagemaker_session = sagemaker.Session(boto_session=boto3.Session())
region = sagemaker_session.boto_region_name
account = sagemaker_session.account_id()

# %% [markdown]
# ### Download Pre-trained Models

# %% [markdown]
# #### Download and Package SAM Checkpoint
# **Apache-2.0 license**

# %%
model_file_name = "sam_vit_h_4b8939.pth"
download_path = f"https://huggingface.co/spaces/abhishek/StableSAM/resolve/main/{model_file_name}"

# !wget $download_path
# Out:
# --2023-05-15 21:26:35--  https://huggingface.co/spaces/abhishek/StableSAM/resolve/main/sam_vit_h_4b8939.pth
# Resolving huggingface.co (huggingface.co)... 18.161.6.70, 18.161.6.77, 18.161.6.48, ...
# Connecting to huggingface.co (huggingface.co)|18.161.6.70|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.huggingface.co/repos/47/d3/47d331d77ce5639cc128df17410f4744b11342191e8442f5cde65f20735d01f9/a7bf3b02f3ebf1267aba913ff637d9a2d5c33d3173bb679e46d9f338c26f262e?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27sam_vit_h_4b8939.pth%3B+filename%3D%22sam_vit_h_4b8939.pth%22%3B&Expires=1684445196&Policy=__&Signature=Y2KRniqgOpT7jQC5rzPtvogP39AnbBYcmlVwGGFEITnz-L5AMkcEb%7E2WtU8%7EMhV2I-kk8iRyIVTR49PrSGHz77-OqThiw1vr67IgyT6sVlJZWJ1Z0KlLK-6uP6ZbEGoRN4IAcPvIn8QzjVfgl1MAWcbEkyoOlHGs%7EzFInFU7IibYJYW4v%7EgIMxWxWIP7vhXOEVw%7EkoQ0U6EaET1oF9s8jzvBkos3ypiTAxHhpGEgeLrCwOJBbsNMyZKN9G46tf%7ElNkFITlNsu9-tC7oXy4FAf0wnGHRKH97TSvcYWU87OeG-ctRE25yhU4ELRssWlFZTC9Dw4kwqAENpg00S0iBFUA__&Key-Pair-Id=KVTP0A1DKRTAX [following]
# --2023-05-15 21:26:35--  https://cdn-lfs.huggingface.co/repos/47/d3/47d331d77ce5639cc128df17410f4744b11342191e8442f5cde65f20735d01f9/a7bf3b02f3ebf1267aba913ff637d9a2d5c33d3173bb679e46d9f338c26f262e?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27sam_vit_h_4b8939.pth%3B+filename%3D%22sam_vit_h_4b8939.pth%22%3B&Expires=1684445196&Policy=__&Signature=Y2KRniqgOpT7jQC5rzPtvogP39AnbBYcmlVwGGFEITnz-L5AMkcEb%7E2WtU8%7EMhV2I-kk8iRyIVTR49PrSGHz77-OqThiw1vr67IgyT6sVlJZWJ1Z0KlLK-6uP6ZbEGoRN4IAcPvIn8QzjVfgl1MAWcbEkyoOlHGs%7EzFInFU7IibYJYW4v%7EgIMxWxWIP7vhXOEVw%7EkoQ0U6EaET1oF9s8jzvBkos3ypiTAxHhpGEgeLrCwOJBbsNMyZKN9G46tf%7ElNkFITlNsu9-tC7oXy4FAf0wnGHRKH97TSvcYWU87OeG-ctRE25yhU4ELRssWlFZTC9Dw4kwqAENpg00S0iBFUA__&Key-Pair-Id=KVTP0A1DKRTAX
# Resolving cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)... 99.84.66.69, 99.84.66.15, 99.84.66.127, ...
# Connecting to cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)|99.84.66.69|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2564550879 (2.4G) [application/zip]
# Saving to: ‘sam_vit_h_4b8939.pth’
#
# 100%[====================================>] 2,564,550,879 41.6MB/s   in 52s
#
# 2023-05-15 21:27:28 (46.9 MB/s) - ‘sam_vit_h_4b8939.pth’ saved [2564550879/2564550879]

# %%
sd_tar = f"docker/{model_file_name}.tar.gz"

def make_tarfile(output_filename, source_dir):
    with tarfile.open(output_filename, "w:gz") as tar:
        tar.add(source_dir, arcname=os.path.basename(source_dir))

make_tarfile(sd_tar, model_file_name)

# %% [markdown]
# ### Download and Package LaMa Checkpoint
# **Apache-2.0 license**

# %%
# !wget https://huggingface.co/smartywu/big-lama/resolve/main/big-lama.zip
# !unzip big-lama.zip
# Out:
# --2023-05-15 21:32:38--  https://huggingface.co/smartywu/big-lama/resolve/main/big-lama.zip
# Resolving huggingface.co (huggingface.co)... 18.161.6.70, 18.161.6.27, 18.161.6.77, ...
# Connecting to huggingface.co (huggingface.co)|18.161.6.70|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.huggingface.co/repos/51/45/51456bfbae988f737d159c165ee79a3168fdd10d70db51da3e2dcc0cb29aa7a5/f1b358ca24093b93a106183b98a3dea6e8ed09f3b43ea7251eb2c81e7b4575f6?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27big-lama.zip%3B+filename%3D%22big-lama.zip%22%3B&response-content-type=application%2Fzip&Expires=1684445559&Policy=...__&Signature=FE6YZ%7EZdsTt1oySbdzXN8EBhHqPAwZpreOPe4u4H-t7yOz8f-OSGsGWjB%7Ez52xMzK4IBoPTtfeiMBKW2KRmy0bop3etvPSM0obT89X7A65VsE2Hv3Yzj2gCodJgTTGvgEU%7EMVSKb2IjSMuVUUaG3um2mnkxUW8QOUym4YK3AyZgxxqWpOb1S8fSXdyMq8dMMwajr2fiVgmuhJKrCoqKzhJH733AfxPupnkQievwq2oaHbWi2hCUwxyDtvztU599XzxIrBvfU%7E3oZRZd3udOXCbwCE13Gol0i9EaT41LBJg3GavJUcA3OOsEpXkkdpLfBEFdOWjbYPlGUHHZDl4Gz3Q__&Key-Pair-Id=KVTP0A1DKRTAX [following]
# --2023-05-15 21:32:39--  https://cdn-lfs.huggingface.co/repos/51/45/51456bfbae988f737d159c165ee79a3168fdd10d70db51da3e2dcc0cb29aa7a5/f1b358ca24093b93a106183b98a3dea6e8ed09f3b43ea7251eb2c81e7b4575f6?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27big-lama.zip%3B+filename%3D%22big-lama.zip%22%3B&response-content-type=application%2Fzip&Expires=1684445559&Policy=...__&Signature=FE6YZ%7EZdsTt1oySbdzXN8EBhHqPAwZpreOPe4u4H-t7yOz8f-OSGsGWjB%7Ez52xMzK4IBoPTtfeiMBKW2KRmy0bop3etvPSM0obT89X7A65VsE2Hv3Yzj2gCodJgTTGvgEU%7EMVSKb2IjSMuVUUaG3um2mnkxUW8QOUym4YK3AyZgxxqWpOb1S8fSXdyMq8dMMwajr2fiVgmuhJKrCoqKzhJH733AfxPupnkQievwq2oaHbWi2hCUwxyDtvztU599XzxIrBvfU%7E3oZRZd3udOXCbwCE13Gol0i9EaT41LBJg3GavJUcA3OOsEpXkkdpLfBEFdOWjbYPlGUHHZDl4Gz3Q__&Key-Pair-Id=KVTP0A1DKRTAX
# Resolving cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)... 99.84.66.15, 99.84.66.127, 99.84.66.69, ...
# Connecting to cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)|99.84.66.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 381428720 (364M) [application/zip]
# Saving to: ‘big-lama.zip’
#
# 100%[======================================>] 381,428,720 45.2MB/s   in 8.0s
#
# 2023-05-15 21:32:47 (45.7 MB/s) - ‘big-lama.zip’ saved [381428720/381428720]
#
# Archive:  big-lama.zip
#   inflating: big-lama/config.yaml
#   inflating: big-lama/models/best.ckpt

# %%
lama_dir = "big-lama"
lama_tar = f"docker/{lama_dir}.tar.gz"

def make_tarfile(output_filename, source_dir):
    with tarfile.open(output_filename, "w:gz") as tar:
        tar.add(source_dir, arcname=os.path.basename(source_dir))

make_tarfile(lama_tar, lama_dir)

# %% [markdown]
# LaMa needs additional source code script. We will clone the repo into our `model_repo` folder

# %%
# !cd model_repo/lama/1 && git clone https://github.com/advimman/lama.git
# Out:
# Cloning into 'lama'...
# remote: Enumerating objects: 399, done.
# remote: Counting objects: 100% (128/128), done.
# remote: Compressing objects: 100% (70/70), done.
# remote: Total 399 (delta 76), reused 68 (delta 55), pack-reused 271
# Receiving objects: 100% (399/399), 9.87 MiB | 16.84 MiB/s, done.
# Resolving deltas: 100% (138/138), done.

# %% [markdown]
# #### Downloading Images and Modules from Inpaint Anything
# **Apache-2.0 license**

# %%
# !cd statics && wget https://github.com/geekyutao/Inpaint-Anything/blob/main/example/fill-anything/sample1.png
# !cd statics && wget https://github.com/geekyutao/Inpaint-Anything/blob/main/example/remove-anything/dog.jpg
# Out:
# --2023-05-20 20:22:31--  https://github.com/geekyutao/Inpaint-Anything/blob/main/example/fill-anything/sample1.png
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sample1.png’
#
#     [ <=>                                   ] 143,273     --.-K/s   in 0.03s
#
# 2023-05-20 20:22:32 (4.20 MB/s) - ‘sample1.png’ saved [143273]
#
# --2023-05-20 20:22:32--  https://github.com/geekyutao/Inpaint-Anything/blob/main/example/remove-anything/dog.jpg
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘dog.jpg’
#
#     [ <=>                                   ] 143,197     --.-K/s   in 0.03s
#
# 2023-05-20 20:22:32 (5.18 MB/s) - ‘dog.jpg’ saved [143197]

# %% [markdown]
# ### Package Conda Environment for each model
#
# SageMaker NVIDIA Triton container images does not contain all the libraries two run our SAM and LaMa models. However, Triton allows you to bring additional dependencies using conda pack. Let's run the two cells below to create a `xxx_env.tar.gz` environment package for each model.

# %%
# !cd docker && bash sam_conda_dependencies.sh
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 23.3.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/ec2-user/anaconda3/envs/sam_env
#
#   added / updated specs:
#     - python=3.8
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2023.5.7   |       hbcca054_0         145 KB  conda-forge
#     libsqlite-3.41.2           |       h2797004_1         800 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         945 KB
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      conda-forge/linux-64::_libgcc_mutex-0.1-conda_forge None
#   _openmp_mutex      conda-forge/linux-64::_openmp_mutex-4.5-2_gnu None
#   bzip2              conda-forge/linux-64::bzip2-1.0.8-h7f98852_4 None
#   ca-certificates    conda-forge/linux-64::ca-certificates-2023.5.7-hbcca054_0 None
#   ld_impl_linux-64   conda-forge/linux-64::ld_impl_linux-64-2.40-h41732ed_0 None
#   libffi             conda-forge/linux-64::libffi-3.4.2-h7f98852_5 None
#   libgcc-ng          conda-forge/linux-64::libgcc-ng-12.2.0-h65d4601_19 None
#   libgomp            conda-forge/linux-64::libgomp-12.2.0-h65d4601_19 None
#   libnsl             conda-forge/linux-64::libnsl-2.0.0-h7f98852_0 None
#   libsqlite          conda-forge/linux-64::libsqlite-3.41.2-h2797004_1 None
#   libuuid            conda-forge/linux-64::libuuid-2.38.1-h0b41bf4_0 None
#   libzlib            conda-forge/linux-64::libzlib-1.2.13-h166bdaf_4 None
#   ncurses            conda-forge/linux-64::ncurses-6.3-h27087fc_1 None
#   openssl            conda-forge/linux-64::openssl-3.1.0-hd590300_3 None
#   pip                conda-forge/noarch::pip-23.1.2-pyhd8ed1ab_0 None
#   python             conda-forge/linux-64::python-3.8.16-he550d4f_1_cpython None
#   readline           conda-forge/linux-64::readline-8.2-h8228510_1 None
#   setuptools         conda-forge/noarch::setuptools-67.7.2-pyhd8ed1ab_0 None
#   tk                 conda-forge/linux-64::tk-8.6.12-h27826a3_0 None
#   wheel              conda-forge/noarch::wheel-0.40.0-pyhd8ed1ab_0 None
#   xz                 conda-forge/linux-64::xz-5.2.6-h166bdaf_0 None
#
#
#
# Downloading and Extracting Packages
# ca-certificates-2023 | 145 KB    | ##################################### | 100%
# libsqlite-3.41.2     | 800 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# #
# # To activate this environment, use
# #
# #     $ conda activate sam_env
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# Retrieving notices: ...working... done
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com, https://pypi.ngc.nvidia.com
# Collecting torch
#   Downloading torch-2.0.1-cp38-cp38-manylinux1_x86_64.whl (619.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 217.4 MB/s eta 0:00:0000:0100:01
# Collecting filelock (from torch)
#   Downloading filelock-3.12.0-py3-none-any.whl (10 kB)
# Collecting typing-extensions (from torch)
#   Downloading typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Collecting sympy (from torch)
#   Downloading sympy-1.12-py3-none-any.whl (5.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 306.7 MB/s eta 0:00:00
# Collecting networkx (from torch)
#   Downloading networkx-3.1-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 303.5 MB/s eta 0:00:00
# Collecting jinja2 (from torch)
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.1/133.1 kB 366.6 MB/s eta 0:00:00
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 247.3 MB/s eta 0:00:00a 0:00:01
# Collecting nvidia-cuda-runtime-cu11==11.7.99 (from torch)
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 402.7 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu11==11.7.101 (from torch)
#   Downloading nvidia_cuda_cupti_cu11-11.7.101-py3-none-manylinux1_x86_64.whl (11.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 204.4 MB/s eta 0:00:00a 0:00:01
# Collecting nvidia-cudnn-cu11==8.5.0.96 (from torch)
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 240.3 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cublas-cu11==11.10.3.66 (from torch)
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 244.5 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cufft-cu11==10.9.0.58 (from torch)
#   Downloading nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux1_x86_64.whl (168.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 220.2 MB/s eta 0:00:00a 0:00:01
# Collecting nvidia-curand-cu11==10.2.10.91 (from torch)
#   Downloading nvidia_curand_cu11-10.2.10.91-py3-none-manylinux1_x86_64.whl (54.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 MB 197.4 MB/s eta 0:00:00a 0:00:01
# Collecting nvidia-cusolver-cu11==11.4.0.1 (from torch)
#   Downloading nvidia_cusolver_cu11-11.4.0.1-2-py3-none-manylinux1_x86_64.whl (102.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.6/102.6 MB 259.9 MB/s eta 0:00:00a 0:00:01
# Collecting nvidia-cusparse-cu11==11.7.4.91 (from torch)
#   Downloading nvidia_cusparse_cu11-11.7.4.91-py3-none-manylinux1_x86_64.whl (173.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.2/173.2 MB 229.0 MB/s eta 0:00:00a 0:00:01
# Collecting nvidia-nccl-cu11==2.14.3 (from torch)
#   Downloading nvidia_nccl_cu11-2.14.3-py3-none-manylinux1_x86_64.whl (177.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.1/177.1 MB 212.2 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-nvtx-cu11==11.7.91 (from torch)
#   Downloading nvidia_nvtx_cu11-11.7.91-py3-none-manylinux1_x86_64.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 kB 310.9 MB/s eta 0:00:00
# Collecting triton==2.0.0 (from torch)
#   Downloading triton-2.0.0-1-cp38-cp38-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.2/63.2 MB 179.0 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/sam_env/lib/python3.8/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (67.7.2)
# Requirement already satisfied: wheel in /home/ec2-user/anaconda3/envs/sam_env/lib/python3.8/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (0.40.0)
# Collecting cmake (from triton==2.0.0->torch)
#   Downloading cmake-3.26.3-py2.py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (24.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.0/24.0 MB 308.8 MB/s eta 0:00:00a 0:00:01
# Collecting lit (from triton==2.0.0->torch)
#   Downloading lit-16.0.3.tar.gz (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.0/138.0 kB 340.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Downloading MarkupSafe-2.1.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Collecting mpmath>=0.19 (from sympy->torch)
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 394.7 MB/s eta 0:00:00
# Building wheels for collected packages: lit
#   Building wheel for lit (setup.py) ... done
#   Created wheel for lit: filename=lit-16.0.3-py3-none-any.whl size=88173 sha256=0b1a8d36deab986f4da212c45707df8a18bdf389d62458308dc8cf0a8490b7c1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-jsxmidzv/wheels/01/20/c2/b32a74e477abe541734225f8d5ed8b9e284d1f8580f6828445
# Successfully built lit
# Installing collected packages: mpmath, lit, cmake, typing-extensions, sympy, nvidia-nvtx-cu11, nvidia-nccl-cu11, nvidia-cusparse-cu11, nvidia-curand-cu11, nvidia-cufft-cu11, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cuda-cupti-cu11, nvidia-cublas-cu11, networkx, MarkupSafe, filelock, nvidia-cusolver-cu11, nvidia-cudnn-cu11, jinja2, triton, torch
# Successfully installed MarkupSafe-2.1.2 cmake-3.26.3 filelock-3.12.0 jinja2-3.1.2 lit-16.0.3 mpmath-1.3.0 networkx-3.1 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-cupti-cu11-11.7.101 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 nvidia-cufft-cu11-10.9.0.58 nvidia-curand-cu11-10.2.10.91 nvidia-cusolver-cu11-11.4.0.1 nvidia-cusparse-cu11-11.7.4.91 nvidia-nccl-cu11-2.14.3 nvidia-nvtx-cu11-11.7.91 sympy-1.12 torch-2.0.1 triton-2.0.0 typing-extensions-4.5.0
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com, https://pypi.ngc.nvidia.com
# Collecting segment-anything-py==1.0
#   Downloading segment_anything_py-1.0-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.2/40.2 kB 7.9 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.7 in /home/ec2-user/anaconda3/envs/sam_env/lib/python3.8/site-packages (from segment-anything-py==1.0) (2.0.1)
# Collecting torchvision>=0.8 (from segment-anything-py==1.0)
#   Downloading torchvision-0.15.2-cp38-cp38-manylinux1_x86_64.whl (33.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.8/33.8 MB 280.6 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: filelock in /home/ec2-user/anaconda3/envs/sam_env/lib/python3.8/site-packages (from torch>=1.7->segment-anything-py==1.0) (3.12.0)
# Requirement already satisfied: typing-extensions in /home/ec2-user/anaconda3/envs/sam_env/lib/python3.8/site-packages (from torch>=1.7->segment-anything-py==1.0) (4.5.0)
# Requirement already satisfied: sympy in /home/ec2-user/anaconda3/envs/sam_env/lib/python3.8/site-packages (from torch>=1.7->segment-anything-py==1.0) (1.12)
# Requirement already satisfied: networkx in /home/ec2-user/anaconda3/envs/sam_env/lib/python3.8/site-packages (from torch>=1.7->segment-anything-py==1.0) (3.1)
# Requirement already satisfied: jinja2 in /home/ec2-user/anaconda3/envs/sam_env/lib/python3.8/site-packages (from torch>=1.7->segment-anything-py==1.0) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/ec2-user/anaconda3/envs/sam_env/lib/python3.8/site-packages (from torch>=1.7->segment-anything-py==1.0) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/ec2-user/anaconda3/envs/sam_env/lib/python3.8/site-packages (from torch>=1.7->segment-anything-py==1.0) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/ec2-user/anaconda3/envs/sam_env/lib/python3.8/site-packages (from torch>=1.7->segment-anything-py==1.0) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/ec2-user/anaconda3/envs/sam_env/lib/python3.8/site-packages (from torch>=1.7->segment-anything-py==1.0) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/ec2-user/anaconda3/envs/sam_env/lib/python3.8/site-packages (from torch>=1.7->segment-anything-py==1.0) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/ec2-user/anaconda3/envs/sam_env/lib/python3.8/site-packages (from torch>=1.7->segment-anything-py==1.0) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/ec2-user/anaconda3/envs/sam_env/lib/python3.8/site-packages (from torch>=1.7->segment-anything-py==1.0) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/ec2-user/anaconda3/envs/sam_env/lib/python3.8/site-packages (from torch>=1.7->segment-anything-py==1.0) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/ec2-user/anaconda3/envs/sam_env/lib/python3.8/site-packages (from torch>=1.7->segment-anything-py==1.0) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/ec2-user/anaconda3/envs/sam_env/lib/python3.8/site-packages (from torch>=1.7->segment-anything-py==1.0) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/ec2-user/anaconda3/envs/sam_env/lib/python3.8/site-packages (from torch>=1.7->segment-anything-py==1.0) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /home/ec2-user/anaconda3/envs/sam_env/lib/python3.8/site-packages (from torch>=1.7->segment-anything-py==1.0) (2.0.0)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/sam_env/lib/python3.8/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.7->segment-anything-py==1.0) (67.7.2)
# Requirement already satisfied: wheel in /home/ec2-user/anaconda3/envs/sam_env/lib/python3.8/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.7->segment-anything-py==1.0) (0.40.0)
# Requirement already satisfied: cmake in /home/ec2-user/anaconda3/envs/sam_env/lib/python3.8/site-packages (from triton==2.0.0->torch>=1.7->segment-anything-py==1.0) (3.26.3)
# Requirement already satisfied: lit in /home/ec2-user/anaconda3/envs/sam_env/lib/python3.8/site-packages (from triton==2.0.0->torch>=1.7->segment-anything-py==1.0) (16.0.3)
# Collecting numpy (from torchvision>=0.8->segment-anything-py==1.0)
#   Downloading numpy-1.24.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 284.5 MB/s eta 0:00:00a 0:00:01
# Collecting requests (from torchvision>=0.8->segment-anything-py==1.0)
#   Downloading requests-2.30.0-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 289.1 MB/s eta 0:00:00
# Collecting pillow!=8.3.*,>=5.3.0 (from torchvision>=0.8->segment-anything-py==1.0)
#   Downloading Pillow-9.5.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 335.8 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ec2-user/anaconda3/envs/sam_env/lib/python3.8/site-packages (from jinja2->torch>=1.7->segment-anything-py==1.0) (2.1.2)
# Collecting charset-normalizer<4,>=2 (from requests->torchvision>=0.8->segment-anything-py==1.0)
#   Downloading charset_normalizer-3.1.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (195 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.9/195.9 kB 323.5 MB/s eta 0:00:00
# Collecting idna<4,>=2.5 (from requests->torchvision>=0.8->segment-anything-py==1.0)
#   Downloading idna-3.4-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.5/61.5 kB 224.1 MB/s eta 0:00:00
# Collecting urllib3<3,>=1.21.1 (from requests->torchvision>=0.8->segment-anything-py==1.0)
#   Downloading urllib3-2.0.2-py3-none-any.whl (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.2/123.2 kB 357.0 MB/s eta 0:00:00
# Collecting certifi>=2017.4.17 (from requests->torchvision>=0.8->segment-anything-py==1.0)
#   Downloading certifi-2023.5.7-py3-none-any.whl (156 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.0/157.0 kB 382.2 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in /home/ec2-user/anaconda3/envs/sam_env/lib/python3.8/site-packages (from sympy->torch>=1.7->segment-anything-py==1.0) (1.3.0)
# Installing collected packages: urllib3, pillow, numpy, idna, charset-normalizer, certifi, requests, torchvision, segment-anything-py
# Successfully installed certifi-2023.5.7 charset-normalizer-3.1.0 idna-3.4 numpy-1.24.3 pillow-9.5.0 requests-2.30.0 segment-anything-py-1.0 torchvision-0.15.2 urllib3-2.0.2
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com, https://pypi.ngc.nvidia.com
# Collecting opencv-python-headless==4.7.0.68
#   Downloading opencv_python_headless-4.7.0.68-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 MB 124.7 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: numpy>=1.17.0 in /home/ec2-user/anaconda3/envs/sam_env/lib/python3.8/site-packages (from opencv-python-headless==4.7.0.68) (1.24.3)
# Installing collected packages: opencv-python-headless
# Successfully installed opencv-python-headless-4.7.0.68
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com, https://pypi.ngc.nvidia.com
# Collecting matplotlib==3.6.3
#   Downloading matplotlib-3.6.3-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (9.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 139.3 MB/s eta 0:00:00 0:00:01
# Collecting contourpy>=1.0.1 (from matplotlib==3.6.3)
#   Downloading contourpy-1.0.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (300 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.0/300.0 kB 374.9 MB/s eta 0:00:00
# Collecting cycler>=0.10 (from matplotlib==3.6.3)
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting fonttools>=4.22.0 (from matplotlib==3.6.3)
#   Downloading fonttools-4.39.4-py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 402.3 MB/s eta 0:00:00
# Collecting kiwisolver>=1.0.1 (from matplotlib==3.6.3)
#   Downloading kiwisolver-1.4.4-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 404.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.19 in /home/ec2-user/anaconda3/envs/sam_env/lib/python3.8/site-packages (from matplotlib==3.6.3) (1.24.3)
# Collecting packaging>=20.0 (from matplotlib==3.6.3)
#   Downloading packaging-23.1-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 274.6 MB/s eta 0:00:00
# Requirement already satisfied: pillow>=6.2.0 in /home/ec2-user/anaconda3/envs/sam_env/lib/python3.8/site-packages (from matplotlib==3.6.3) (9.5.0)
# Collecting pyparsing>=2.2.1 (from matplotlib==3.6.3)
#   Downloading pyparsing-3.0.9-py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.3/98.3 kB 317.4 MB/s eta 0:00:00
# Collecting python-dateutil>=2.7 (from matplotlib==3.6.3)
#   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.7/247.7 kB 399.2 MB/s eta 0:00:00
# Collecting six>=1.5 (from python-dateutil>=2.7->matplotlib==3.6.3)
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Installing collected packages: six, pyparsing, packaging, kiwisolver, fonttools, cycler, contourpy, python-dateutil, matplotlib
# Successfully installed contourpy-1.0.7 cycler-0.11.0 fonttools-4.39.4 kiwisolver-1.4.4 matplotlib-3.6.3 packaging-23.1 pyparsing-3.0.9 python-dateutil-2.8.2 six-1.16.0
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com, https://pypi.ngc.nvidia.com
# Collecting conda-pack
#   Downloading conda-pack-0.6.0.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 4.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/sam_env/lib/python3.8/site-packages (from conda-pack) (67.7.2)
# Building wheels for collected packages: conda-pack
#   Building wheel for conda-pack (setup.py) ... done
#   Created wheel for conda-pack: filename=conda_pack-0.6.0-py2.py3-none-any.whl size=30883 sha256=f5b717d273a1a90b8c159afcfca72a838d078197534cc09f37caf8a3f43e961a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-___xdxmi/wheels/56/1b/9e/0da27a4c18349d8f048a8fe87d763d75d3098384e9fa285e45
# Successfully built conda-pack
# Installing collected packages: conda-pack
# Successfully installed conda-pack-0.6.0
# Collecting packages...
# Packing environment at '/home/ec2-user/anaconda3/envs/sam_env' to 'sam_env.tar.gz'
# [########################################] | 100% Completed |  2min 48.0s

# %%
# !cd docker && bash lama_conda_dependencies.sh
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 23.3.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/ec2-user/anaconda3/envs/lama_env
#
#   added / updated specs:
#     - python=3.8
#
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      conda-forge/linux-64::_libgcc_mutex-0.1-conda_forge None
#   _openmp_mutex      conda-forge/linux-64::_openmp_mutex-4.5-2_gnu None
#   bzip2              conda-forge/linux-64::bzip2-1.0.8-h7f98852_4 None
#   ca-certificates    conda-forge/linux-64::ca-certificates-2023.5.7-hbcca054_0 None
#   ld_impl_linux-64   conda-forge/linux-64::ld_impl_linux-64-2.40-h41732ed_0 None
#   libffi             conda-forge/linux-64::libffi-3.4.2-h7f98852_5 None
#   libgcc-ng          conda-forge/linux-64::libgcc-ng-12.2.0-h65d4601_19 None
#   libgomp            conda-forge/linux-64::libgomp-12.2.0-h65d4601_19 None
#   libnsl             conda-forge/linux-64::libnsl-2.0.0-h7f98852_0 None
#   libsqlite          conda-forge/linux-64::libsqlite-3.41.2-h2797004_1 None
#   libuuid            conda-forge/linux-64::libuuid-2.38.1-h0b41bf4_0 None
#   libzlib            conda-forge/linux-64::libzlib-1.2.13-h166bdaf_4 None
#   ncurses            conda-forge/linux-64::ncurses-6.3-h27087fc_1 None
#   openssl            conda-forge/linux-64::openssl-3.1.0-hd590300_3 None
#   pip                conda-forge/noarch::pip-23.1.2-pyhd8ed1ab_0 None
#   python             conda-forge/linux-64::python-3.8.16-he550d4f_1_cpython None
#   readline           conda-forge/linux-64::readline-8.2-h8228510_1 None
#   setuptools         conda-forge/noarch::setuptools-67.7.2-pyhd8ed1ab_0 None
#   tk                 conda-forge/linux-64::tk-8.6.12-h27826a3_0 None
#   wheel              conda-forge/noarch::wheel-0.40.0-pyhd8ed1ab_0 None
#   xz                 conda-forge/linux-64::xz-5.2.6-h166bdaf_0 None
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# #
# # To activate this environment, use
# #
# #     $ conda activate lama_env
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# Retrieving notices: ...working... done
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com, https://pypi.ngc.nvidia.com
# Collecting torch
#   Downloading torch-2.0.1-cp38-cp38-manylinux1_x86_64.whl (619.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 228.3 MB/s eta 0:00:0000:0100:01
# Collecting filelock (from torch)
#   Downloading filelock-3.12.0-py3-none-any.whl (10 kB)
# Collecting typing-extensions (from torch)
#   Downloading typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Collecting sympy (from torch)
#   Downloading sympy-1.12-py3-none-any.whl (5.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 243.8 MB/s eta 0:00:00
# Collecting networkx (from torch)
#   Downloading networkx-3.1-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 339.7 MB/s eta 0:00:00
# Collecting jinja2 (from torch)
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.1/133.1 kB 381.0 MB/s eta 0:00:00
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 294.9 MB/s eta 0:00:00a 0:00:01
# Collecting nvidia-cuda-runtime-cu11==11.7.99 (from torch)
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 403.1 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu11==11.7.101 (from torch)
#   Downloading nvidia_cuda_cupti_cu11-11.7.101-py3-none-manylinux1_x86_64.whl (11.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 269.9 MB/s eta 0:00:00a 0:00:01
# Collecting nvidia-cudnn-cu11==8.5.0.96 (from torch)
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 232.4 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cublas-cu11==11.10.3.66 (from torch)
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 292.9 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cufft-cu11==10.9.0.58 (from torch)
#   Downloading nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux1_x86_64.whl (168.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 222.7 MB/s eta 0:00:00a 0:00:01
# Collecting nvidia-curand-cu11==10.2.10.91 (from torch)
#   Downloading nvidia_curand_cu11-10.2.10.91-py3-none-manylinux1_x86_64.whl (54.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 MB 176.1 MB/s eta 0:00:00a 0:00:01
# Collecting nvidia-cusolver-cu11==11.4.0.1 (from torch)
#   Downloading nvidia_cusolver_cu11-11.4.0.1-2-py3-none-manylinux1_x86_64.whl (102.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.6/102.6 MB 234.3 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cusparse-cu11==11.7.4.91 (from torch)
#   Downloading nvidia_cusparse_cu11-11.7.4.91-py3-none-manylinux1_x86_64.whl (173.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.2/173.2 MB 224.0 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-nccl-cu11==2.14.3 (from torch)
#   Downloading nvidia_nccl_cu11-2.14.3-py3-none-manylinux1_x86_64.whl (177.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.1/177.1 MB 251.6 MB/s eta 0:00:00a 0:00:01
# Collecting nvidia-nvtx-cu11==11.7.91 (from torch)
#   Downloading nvidia_nvtx_cu11-11.7.91-py3-none-manylinux1_x86_64.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 kB 306.8 MB/s eta 0:00:00
# Collecting triton==2.0.0 (from torch)
#   Downloading triton-2.0.0-1-cp38-cp38-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.2/63.2 MB 262.6 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (67.7.2)
# Requirement already satisfied: wheel in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (0.40.0)
# Collecting cmake (from triton==2.0.0->torch)
#   Downloading cmake-3.26.3-py2.py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (24.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.0/24.0 MB 177.4 MB/s eta 0:00:00a 0:00:01
# Collecting lit (from triton==2.0.0->torch)
#   Downloading lit-16.0.3.tar.gz (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.0/138.0 kB 340.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Downloading MarkupSafe-2.1.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Collecting mpmath>=0.19 (from sympy->torch)
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 412.2 MB/s eta 0:00:00
# Building wheels for collected packages: lit
#   Building wheel for lit (setup.py) ... done
#   Created wheel for lit: filename=lit-16.0.3-py3-none-any.whl size=88173 sha256=051e3243a013eb56115e4eab9990a89f48b56aea876c0a533bc14bd6c255c5be
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hgpjviqx/wheels/01/20/c2/b32a74e477abe541734225f8d5ed8b9e284d1f8580f6828445
# Successfully built lit
# Installing collected packages: mpmath, lit, cmake, typing-extensions, sympy, nvidia-nvtx-cu11, nvidia-nccl-cu11, nvidia-cusparse-cu11, nvidia-curand-cu11, nvidia-cufft-cu11, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cuda-cupti-cu11, nvidia-cublas-cu11, networkx, MarkupSafe, filelock, nvidia-cusolver-cu11, nvidia-cudnn-cu11, jinja2, triton, torch
# Successfully installed MarkupSafe-2.1.2 cmake-3.26.3 filelock-3.12.0 jinja2-3.1.2 lit-16.0.3 mpmath-1.3.0 networkx-3.1 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-cupti-cu11-11.7.101 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 nvidia-cufft-cu11-10.9.0.58 nvidia-curand-cu11-10.2.10.91 nvidia-cusolver-cu11-11.4.0.1 nvidia-cusparse-cu11-11.7.4.91 nvidia-nccl-cu11-2.14.3 nvidia-nvtx-cu11-11.7.91 sympy-1.12 torch-2.0.1 triton-2.0.0 typing-extensions-4.5.0
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com, https://pypi.ngc.nvidia.com
# Collecting opencv-python
#   Downloading opencv_python-4.7.0.72-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (61.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.8/61.8 MB 276.4 MB/s eta 0:00:00a 0:00:01
# Collecting numpy>=1.17.0 (from opencv-python)
#   Downloading numpy-1.24.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 267.4 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: numpy, opencv-python
# Successfully installed numpy-1.24.3 opencv-python-4.7.0.72
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com, https://pypi.ngc.nvidia.com
# Collecting pyyaml
#   Downloading PyYAML-6.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (701 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 701.2/701.2 kB 18.2 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: pyyaml
# Successfully installed pyyaml-6.0
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com, https://pypi.ngc.nvidia.com
# Collecting tqdm
#   Downloading tqdm-4.65.0-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 5.9 MB/s eta 0:00:00
# Installing collected packages: tqdm
# Successfully installed tqdm-4.65.0
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com, https://pypi.ngc.nvidia.com
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (1.24.3)
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com, https://pypi.ngc.nvidia.com
# Collecting easydict==1.9.0
#   Downloading easydict-1.9.tar.gz (6.4 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: easydict
#   Building wheel for easydict (setup.py) ... done
#   Created wheel for easydict: filename=easydict-1.9-py3-none-any.whl size=6344 sha256=fcff6c6106e0d2763e4536f82ecd6c01cca369e26cb81db1441447dd9be56790
#   Stored in directory: /tmp/pip-ephem-wheel-cache-02o4jvgc/wheels/d3/e0/e9/305e348717e399665119bd012510d51ff4f22d709ff60c3096
# Successfully built easydict
# Installing collected packages: easydict
# Successfully installed easydict-1.9
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com, https://pypi.ngc.nvidia.com
# Collecting scikit-image==0.17.2
#   Downloading scikit_image-0.17.2-cp38-cp38-manylinux1_x86_64.whl (12.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 222.1 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: numpy>=1.15.1 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from scikit-image==0.17.2) (1.24.3)
# Collecting scipy>=1.0.1 (from scikit-image==0.17.2)
#   Downloading scipy-1.10.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 298.4 MB/s eta 0:00:00a 0:00:01
# Collecting matplotlib!=3.0.0,>=2.0.0 (from scikit-image==0.17.2)
#   Downloading matplotlib-3.7.1-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (9.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 296.4 MB/s eta 0:00:00
# Requirement already satisfied: networkx>=2.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from scikit-image==0.17.2) (3.1)
# Collecting pillow!=7.1.0,!=7.1.1,>=4.3.0 (from scikit-image==0.17.2)
#   Downloading Pillow-9.5.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 275.9 MB/s eta 0:00:00
# Collecting imageio>=2.3.0 (from scikit-image==0.17.2)
#   Downloading imageio-2.28.1-py3-none-any.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 318.4 MB/s eta 0:00:00
# Collecting tifffile>=2019.7.26 (from scikit-image==0.17.2)
#   Downloading tifffile-2023.4.12-py3-none-any.whl (219 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.4/219.4 kB 348.2 MB/s eta 0:00:00
# Collecting PyWavelets>=1.1.1 (from scikit-image==0.17.2)
#   Downloading PyWavelets-1.4.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 311.9 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1 (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.17.2)
#   Downloading contourpy-1.0.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (300 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.0/300.0 kB 376.7 MB/s eta 0:00:00
# Collecting cycler>=0.10 (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.17.2)
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting fonttools>=4.22.0 (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.17.2)
#   Downloading fonttools-4.39.4-py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 385.7 MB/s eta 0:00:00
# Collecting kiwisolver>=1.0.1 (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.17.2)
#   Downloading kiwisolver-1.4.4-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 392.4 MB/s eta 0:00:00
# Collecting packaging>=20.0 (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.17.2)
#   Downloading packaging-23.1-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 326.0 MB/s eta 0:00:00
# Collecting pyparsing>=2.3.1 (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.17.2)
#   Downloading pyparsing-3.0.9-py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.3/98.3 kB 316.4 MB/s eta 0:00:00
# Collecting python-dateutil>=2.7 (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.17.2)
#   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.7/247.7 kB 383.0 MB/s eta 0:00:00
# Collecting importlib-resources>=3.2.0 (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.17.2)
#   Downloading importlib_resources-5.12.0-py3-none-any.whl (36 kB)
# Collecting zipp>=3.1.0 (from importlib-resources>=3.2.0->matplotlib!=3.0.0,>=2.0.0->scikit-image==0.17.2)
#   Downloading zipp-3.15.0-py3-none-any.whl (6.8 kB)
# Collecting six>=1.5 (from python-dateutil>=2.7->matplotlib!=3.0.0,>=2.0.0->scikit-image==0.17.2)
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Installing collected packages: zipp, tifffile, six, scipy, PyWavelets, pyparsing, pillow, packaging, kiwisolver, fonttools, cycler, contourpy, python-dateutil, importlib-resources, imageio, matplotlib, scikit-image
# Successfully installed PyWavelets-1.4.1 contourpy-1.0.7 cycler-0.11.0 fonttools-4.39.4 imageio-2.28.1 importlib-resources-5.12.0 kiwisolver-1.4.4 matplotlib-3.7.1 packaging-23.1 pillow-9.5.0 pyparsing-3.0.9 python-dateutil-2.8.2 scikit-image-0.17.2 scipy-1.10.1 six-1.16.0 tifffile-2023.4.12 zipp-3.15.0
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com, https://pypi.ngc.nvidia.com
# Collecting scikit-learn==0.24.2
#   Downloading scikit_learn-0.24.2-cp38-cp38-manylinux2010_x86_64.whl (24.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.9/24.9 MB 265.0 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: numpy>=1.13.3 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from scikit-learn==0.24.2) (1.24.3)
# Requirement already satisfied: scipy>=0.19.1 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from scikit-learn==0.24.2) (1.10.1)
# Collecting joblib>=0.11 (from scikit-learn==0.24.2)
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 387.0 MB/s eta 0:00:00
# Collecting threadpoolctl>=2.0.0 (from scikit-learn==0.24.2)
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
# Successfully installed joblib-1.2.0 scikit-learn-0.24.2 threadpoolctl-3.1.0
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com, https://pypi.ngc.nvidia.com
# Collecting tensorflow
#   Downloading tensorflow-2.12.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (585.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 585.9/585.9 MB 247.3 MB/s eta 0:00:0000:0100:01
# Collecting absl-py>=1.0.0 (from tensorflow)
#   Downloading absl_py-1.4.0-py3-none-any.whl (126 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.5/126.5 kB 371.9 MB/s eta 0:00:00
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting flatbuffers>=2.0 (from tensorflow)
#   Downloading flatbuffers-23.5.9-py2.py3-none-any.whl (26 kB)
# Collecting gast<=0.4.0,>=0.2.1 (from tensorflow)
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow)
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 305.8 MB/s eta 0:00:00
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow)
#   Downloading grpcio-1.54.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 316.4 MB/s eta 0:00:00
# Collecting h5py>=2.9.0 (from tensorflow)
#   Downloading h5py-3.8.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 180.9 MB/s eta 0:00:00
# Collecting jax>=0.3.15 (from tensorflow)
#   Downloading jax-0.4.10.tar.gz (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 407.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting keras<2.13,>=2.12.0 (from tensorflow)
#   Downloading keras-2.12.0-py2.py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 345.4 MB/s eta 0:00:00
# Collecting libclang>=13.0.0 (from tensorflow)
#   Downloading libclang-16.0.0-py2.py3-none-manylinux2010_x86_64.whl (22.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.9/22.9 MB 245.9 MB/s eta 0:00:00a 0:00:01
# Collecting numpy<1.24,>=1.22 (from tensorflow)
#   Downloading numpy-1.23.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 213.8 MB/s eta 0:00:00a 0:00:01
# Collecting opt-einsum>=2.3.2 (from tensorflow)
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 312.8 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from tensorflow) (23.1)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow)
#   Downloading protobuf-4.23.0-cp37-abi3-manylinux2014_x86_64.whl (304 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.5/304.5 kB 384.9 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from tensorflow) (1.16.0)
# Collecting tensorboard<2.13,>=2.12 (from tensorflow)
#   Downloading tensorboard-2.12.3-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 295.0 MB/s eta 0:00:00
# Collecting tensorflow-estimator<2.13,>=2.12.0 (from tensorflow)
#   Downloading tensorflow_estimator-2.12.0-py2.py3-none-any.whl (440 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 440.7/440.7 kB 380.1 MB/s eta 0:00:00
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Downloading termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from tensorflow) (4.5.0)
# Collecting wrapt<1.15,>=1.11.0 (from tensorflow)
#   Downloading wrapt-1.14.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.0/81.0 kB 323.3 MB/s eta 0:00:00
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow)
#   Downloading tensorflow_io_gcs_filesystem-0.32.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 341.7 MB/s eta 0:00:00
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from astunparse>=1.6.0->tensorflow) (0.40.0)
# Collecting ml-dtypes>=0.1.0 (from jax>=0.3.15->tensorflow)
#   Downloading ml_dtypes-0.1.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 363.7 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.7 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from jax>=0.3.15->tensorflow) (1.10.1)
# Collecting google-auth<3,>=1.6.3 (from tensorboard<2.13,>=2.12->tensorflow)
#   Downloading google_auth-2.18.0-py2.py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.9/178.9 kB 341.1 MB/s eta 0:00:00
# Collecting google-auth-oauthlib<1.1,>=0.5 (from tensorboard<2.13,>=2.12->tensorflow)
#   Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Collecting markdown>=2.6.8 (from tensorboard<2.13,>=2.12->tensorflow)
#   Downloading Markdown-3.4.3-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.9/93.9 kB 348.9 MB/s eta 0:00:00
# Collecting requests<3,>=2.21.0 (from tensorboard<2.13,>=2.12->tensorflow)
#   Downloading requests-2.30.0-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 277.9 MB/s eta 0:00:00
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.13,>=2.12->tensorflow)
#   Downloading tensorboard_data_server-0.7.0-py3-none-manylinux2014_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 253.2 MB/s eta 0:00:00
# Collecting werkzeug>=1.0.1 (from tensorboard<2.13,>=2.12->tensorflow)
#   Downloading Werkzeug-2.3.4-py3-none-any.whl (242 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.5/242.5 kB 362.4 MB/s eta 0:00:00
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow)
#   Downloading cachetools-5.3.0-py3-none-any.whl (9.3 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow)
#   Downloading pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 kB 389.2 MB/s eta 0:00:00
# Collecting urllib3<2.0 (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow)
#   Downloading urllib3-1.26.15-py2.py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.9/140.9 kB 348.5 MB/s eta 0:00:00
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow)
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow)
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting importlib-metadata>=4.4 (from markdown>=2.6.8->tensorboard<2.13,>=2.12->tensorflow)
#   Downloading importlib_metadata-6.6.0-py3-none-any.whl (22 kB)
# Collecting charset-normalizer<4,>=2 (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow)
#   Downloading charset_normalizer-3.1.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (195 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.9/195.9 kB 315.4 MB/s eta 0:00:00
# Collecting idna<4,>=2.5 (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow)
#   Downloading idna-3.4-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.5/61.5 kB 309.4 MB/s eta 0:00:00
# Collecting certifi>=2017.4.17 (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow)
#   Downloading certifi-2023.5.7-py3-none-any.whl (156 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.0/157.0 kB 354.6 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.13,>=2.12->tensorflow) (3.15.0)
# Collecting pyasn1<0.6.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow)
#   Downloading pyasn1-0.5.0-py2.py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.9/83.9 kB 337.6 MB/s eta 0:00:00
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow)
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 360.7 MB/s eta 0:00:00
# Building wheels for collected packages: jax
#   Building wheel for jax (pyproject.toml) ... done
#   Created wheel for jax: filename=jax-0.4.10-py3-none-any.whl size=1480503 sha256=51164eb7f41b237a46f7c49f68aaaf003e194313c9e5f20c25a174f6fde05971
#   Stored in directory: /tmp/pip-ephem-wheel-cache-bv89fec2/wheels/6a/8c/35/209bfba5979c08e883a5cfcb9f3ddf907f9dd1c37ee83c1f8d
# Successfully built jax
# Installing collected packages: libclang, flatbuffers, wrapt, werkzeug, urllib3, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, pyasn1, protobuf, oauthlib, numpy, keras, importlib-metadata, idna, grpcio, google-pasta, gast, charset-normalizer, certifi, cachetools, astunparse, absl-py, rsa, requests, pyasn1-modules, opt-einsum, ml-dtypes, markdown, h5py, requests-oauthlib, jax, google-auth, google-auth-oauthlib, tensorboard, tensorflow
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.3
#     Uninstalling numpy-1.24.3:
#       Successfully uninstalled numpy-1.24.3
# Successfully installed absl-py-1.4.0 astunparse-1.6.3 cachetools-5.3.0 certifi-2023.5.7 charset-normalizer-3.1.0 flatbuffers-23.5.9 gast-0.4.0 google-auth-2.18.0 google-auth-oauthlib-1.0.0 google-pasta-0.2.0 grpcio-1.54.2 h5py-3.8.0 idna-3.4 importlib-metadata-6.6.0 jax-0.4.10 keras-2.12.0 libclang-16.0.0 markdown-3.4.3 ml-dtypes-0.1.0 numpy-1.23.5 oauthlib-3.2.2 opt-einsum-3.3.0 protobuf-4.23.0 pyasn1-0.5.0 pyasn1-modules-0.3.0 requests-2.30.0 requests-oauthlib-1.3.1 rsa-4.9 tensorboard-2.12.3 tensorboard-data-server-0.7.0 tensorflow-2.12.0 tensorflow-estimator-2.12.0 tensorflow-io-gcs-filesystem-0.32.0 termcolor-2.3.0 urllib3-1.26.15 werkzeug-2.3.4 wrapt-1.14.1
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com, https://pypi.ngc.nvidia.com
# Requirement already satisfied: joblib in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (1.2.0)
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com, https://pypi.ngc.nvidia.com
# Requirement already satisfied: matplotlib in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from matplotlib) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from matplotlib) (5.12.0)
# Requirement already satisfied: zipp>=3.1.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.15.0)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com, https://pypi.ngc.nvidia.com
# Collecting pandas
#   Downloading pandas-2.0.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 243.1 MB/s eta 0:00:00 0:00:01
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from pandas) (2.8.2)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2023.3-py2.py3-none-any.whl (502 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 502.3/502.3 kB 405.3 MB/s eta 0:00:00
# Collecting tzdata>=2022.1 (from pandas)
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 389.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20.3 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Installing collected packages: pytz, tzdata, pandas
# Successfully installed pandas-2.0.1 pytz-2023.3 tzdata-2023.3
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com, https://pypi.ngc.nvidia.com
# Collecting albumentations==0.5.2
#   Downloading albumentations-0.5.2-py3-none-any.whl (72 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.2/72.2 kB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.11.1 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from albumentations==0.5.2) (1.23.5)
# Requirement already satisfied: scipy in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from albumentations==0.5.2) (1.10.1)
# Requirement already satisfied: scikit-image>=0.16.1 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from albumentations==0.5.2) (0.17.2)
# Collecting imgaug>=0.4.0 (from albumentations==0.5.2)
#   Downloading imgaug-0.4.0-py2.py3-none-any.whl (948 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 948.0/948.0 kB 32.7 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from albumentations==0.5.2) (6.0)
# Collecting opencv-python-headless>=4.1.1 (from albumentations==0.5.2)
#   Downloading opencv_python_headless-4.7.0.72-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 MB 279.4 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: six in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from imgaug>=0.4.0->albumentations==0.5.2) (1.16.0)
# Requirement already satisfied: Pillow in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from imgaug>=0.4.0->albumentations==0.5.2) (9.5.0)
# Requirement already satisfied: matplotlib in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from imgaug>=0.4.0->albumentations==0.5.2) (3.7.1)
# Requirement already satisfied: opencv-python in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from imgaug>=0.4.0->albumentations==0.5.2) (4.7.0.72)
# Requirement already satisfied: imageio in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from imgaug>=0.4.0->albumentations==0.5.2) (2.28.1)
# Collecting Shapely (from imgaug>=0.4.0->albumentations==0.5.2)
#   Downloading shapely-2.0.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 330.0 MB/s eta 0:00:00
# Requirement already satisfied: networkx>=2.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from scikit-image>=0.16.1->albumentations==0.5.2) (3.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from scikit-image>=0.16.1->albumentations==0.5.2) (2023.4.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from scikit-image>=0.16.1->albumentations==0.5.2) (1.4.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from matplotlib->imgaug>=0.4.0->albumentations==0.5.2) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from matplotlib->imgaug>=0.4.0->albumentations==0.5.2) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from matplotlib->imgaug>=0.4.0->albumentations==0.5.2) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from matplotlib->imgaug>=0.4.0->albumentations==0.5.2) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from matplotlib->imgaug>=0.4.0->albumentations==0.5.2) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from matplotlib->imgaug>=0.4.0->albumentations==0.5.2) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from matplotlib->imgaug>=0.4.0->albumentations==0.5.2) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from matplotlib->imgaug>=0.4.0->albumentations==0.5.2) (5.12.0)
# Requirement already satisfied: zipp>=3.1.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib->imgaug>=0.4.0->albumentations==0.5.2) (3.15.0)
# Installing collected packages: Shapely, opencv-python-headless, imgaug, albumentations
# Successfully installed Shapely-2.0.1 albumentations-0.5.2 imgaug-0.4.0 opencv-python-headless-4.7.0.72
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com, https://pypi.ngc.nvidia.com
# Collecting hydra-core==1.1.0
#   Downloading hydra_core-1.1.0-py3-none-any.whl (144 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.6/144.6 kB 6.5 MB/s eta 0:00:00
# Collecting omegaconf==2.1.* (from hydra-core==1.1.0)
#   Downloading omegaconf-2.1.2-py3-none-any.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.7/74.7 kB 309.7 MB/s eta 0:00:00
# Collecting antlr4-python3-runtime==4.8 (from hydra-core==1.1.0)
#   Downloading antlr4-python3-runtime-4.8.tar.gz (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.4/112.4 kB 300.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: importlib-resources in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from hydra-core==1.1.0) (5.12.0)
# Requirement already satisfied: PyYAML>=5.1.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from omegaconf==2.1.*->hydra-core==1.1.0) (6.0)
# Requirement already satisfied: zipp>=3.1.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from importlib-resources->hydra-core==1.1.0) (3.15.0)
# Building wheels for collected packages: antlr4-python3-runtime
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.8-py3-none-any.whl size=141210 sha256=b7ba56330d47319dbbb5d157f09f72cd7e2bb62137e479e20d9964451682bf64
#   Stored in directory: /tmp/pip-ephem-wheel-cache-xbadtycd/wheels/c8/d0/ab/d43c02eaddc5b9004db86950802442ad9a26f279c619e28da0
# Successfully built antlr4-python3-runtime
# Installing collected packages: antlr4-python3-runtime, omegaconf, hydra-core
# Successfully installed antlr4-python3-runtime-4.8 hydra-core-1.1.0 omegaconf-2.1.2
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com, https://pypi.ngc.nvidia.com
# Collecting pytorch-lightning==1.2.9
#   Downloading pytorch_lightning-1.2.9-py3-none-any.whl (841 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 841.9/841.9 kB 18.0 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: numpy>=1.16.6 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from pytorch-lightning==1.2.9) (1.23.5)
# Requirement already satisfied: torch>=1.4 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from pytorch-lightning==1.2.9) (2.0.1)
# Collecting future>=0.17.1 (from pytorch-lightning==1.2.9)
#   Downloading future-0.18.3.tar.gz (840 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 840.9/840.9 kB 348.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: PyYAML!=5.4.*,>=5.1 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from pytorch-lightning==1.2.9) (6.0)
# Requirement already satisfied: tqdm>=4.41.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from pytorch-lightning==1.2.9) (4.65.0)
# Collecting fsspec[http]>=0.8.1 (from pytorch-lightning==1.2.9)
#   Downloading fsspec-2023.5.0-py3-none-any.whl (160 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.1/160.1 kB 378.9 MB/s eta 0:00:00
# Requirement already satisfied: tensorboard!=2.5.0,>=2.2.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from pytorch-lightning==1.2.9) (2.12.3)
# Collecting torchmetrics==0.2.0 (from pytorch-lightning==1.2.9)
#   Downloading torchmetrics-0.2.0-py3-none-any.whl (176 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.9/176.9 kB 330.2 MB/s eta 0:00:00
# Requirement already satisfied: requests in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from fsspec[http]>=0.8.1->pytorch-lightning==1.2.9) (2.30.0)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]>=0.8.1->pytorch-lightning==1.2.9)
#   Downloading aiohttp-3.8.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 342.4 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=0.4 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.9) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.9) (1.54.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.9) (2.18.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.9) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.9) (3.4.3)
# Requirement already satisfied: protobuf>=3.19.6 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.9) (4.23.0)
# Requirement already satisfied: setuptools>=41.0.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.9) (67.7.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.9) (0.7.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.9) (2.3.4)
# Requirement already satisfied: wheel>=0.26 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.9) (0.40.0)
# Requirement already satisfied: filelock in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch>=1.4->pytorch-lightning==1.2.9) (3.12.0)
# Requirement already satisfied: typing-extensions in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch>=1.4->pytorch-lightning==1.2.9) (4.5.0)
# Requirement already satisfied: sympy in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch>=1.4->pytorch-lightning==1.2.9) (1.12)
# Requirement already satisfied: networkx in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch>=1.4->pytorch-lightning==1.2.9) (3.1)
# Requirement already satisfied: jinja2 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch>=1.4->pytorch-lightning==1.2.9) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch>=1.4->pytorch-lightning==1.2.9) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch>=1.4->pytorch-lightning==1.2.9) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch>=1.4->pytorch-lightning==1.2.9) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch>=1.4->pytorch-lightning==1.2.9) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch>=1.4->pytorch-lightning==1.2.9) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch>=1.4->pytorch-lightning==1.2.9) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch>=1.4->pytorch-lightning==1.2.9) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch>=1.4->pytorch-lightning==1.2.9) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch>=1.4->pytorch-lightning==1.2.9) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch>=1.4->pytorch-lightning==1.2.9) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch>=1.4->pytorch-lightning==1.2.9) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch>=1.4->pytorch-lightning==1.2.9) (2.0.0)
# Requirement already satisfied: cmake in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from triton==2.0.0->torch>=1.4->pytorch-lightning==1.2.9) (3.26.3)
# Requirement already satisfied: lit in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from triton==2.0.0->torch>=1.4->pytorch-lightning==1.2.9) (16.0.3)
# Collecting attrs>=17.3.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=0.8.1->pytorch-lightning==1.2.9)
#   Downloading attrs-23.1.0-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 323.8 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=0.8.1->pytorch-lightning==1.2.9) (3.1.0)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=0.8.1->pytorch-lightning==1.2.9)
#   Downloading multidict-6.0.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.3/121.3 kB 348.8 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=0.8.1->pytorch-lightning==1.2.9)
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=0.8.1->pytorch-lightning==1.2.9)
#   Downloading yarl-1.9.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (266 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.9/266.9 kB 339.1 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=0.8.1->pytorch-lightning==1.2.9)
#   Downloading frozenlist-1.3.3-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (161 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.3/161.3 kB 364.1 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=0.8.1->pytorch-lightning==1.2.9)
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.9) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.9) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.9) (1.16.0)
# Requirement already satisfied: urllib3<2.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.9) (1.26.15)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.9) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.9) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.9) (6.6.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from requests->fsspec[http]>=0.8.1->pytorch-lightning==1.2.9) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from requests->fsspec[http]>=0.8.1->pytorch-lightning==1.2.9) (2023.5.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from werkzeug>=1.0.1->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.9) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from sympy->torch>=1.4->pytorch-lightning==1.2.9) (1.3.0)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.9) (3.15.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.9) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.9) (3.2.2)
# Building wheels for collected packages: future
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.3-py3-none-any.whl size=492022 sha256=a021e5eb1c9350f151503dccbb5e2b4bbefd5eebd29150ebdd18a3cc7a1b575e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-g24z6rxc/wheels/a0/0b/ee/e6994fadb42c1354dcccb139b0bf2795271bddfe6253ccdf11
# Successfully built future
# Installing collected packages: multidict, future, fsspec, frozenlist, attrs, async-timeout, yarl, aiosignal, aiohttp, torchmetrics, pytorch-lightning
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 attrs-23.1.0 frozenlist-1.3.3 fsspec-2023.5.0 future-0.18.3 multidict-6.0.4 pytorch-lightning-1.2.9 torchmetrics-0.2.0 yarl-1.9.2
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com, https://pypi.ngc.nvidia.com
# Collecting tabulate
#   Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Installing collected packages: tabulate
# Successfully installed tabulate-0.9.0
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com, https://pypi.ngc.nvidia.com
# Collecting kornia==0.5.0
#   Downloading kornia-0.5.0-py2.py3-none-any.whl (271 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 271.5/271.5 kB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from kornia==0.5.0) (1.23.5)
# Requirement already satisfied: torch>=1.6.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from kornia==0.5.0) (2.0.1)
# Requirement already satisfied: filelock in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch>=1.6.0->kornia==0.5.0) (3.12.0)
# Requirement already satisfied: typing-extensions in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch>=1.6.0->kornia==0.5.0) (4.5.0)
# Requirement already satisfied: sympy in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch>=1.6.0->kornia==0.5.0) (1.12)
# Requirement already satisfied: networkx in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch>=1.6.0->kornia==0.5.0) (3.1)
# Requirement already satisfied: jinja2 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch>=1.6.0->kornia==0.5.0) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch>=1.6.0->kornia==0.5.0) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch>=1.6.0->kornia==0.5.0) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch>=1.6.0->kornia==0.5.0) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch>=1.6.0->kornia==0.5.0) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch>=1.6.0->kornia==0.5.0) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch>=1.6.0->kornia==0.5.0) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch>=1.6.0->kornia==0.5.0) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch>=1.6.0->kornia==0.5.0) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch>=1.6.0->kornia==0.5.0) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch>=1.6.0->kornia==0.5.0) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch>=1.6.0->kornia==0.5.0) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch>=1.6.0->kornia==0.5.0) (2.0.0)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.6.0->kornia==0.5.0) (67.7.2)
# Requirement already satisfied: wheel in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.6.0->kornia==0.5.0) (0.40.0)
# Requirement already satisfied: cmake in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from triton==2.0.0->torch>=1.6.0->kornia==0.5.0) (3.26.3)
# Requirement already satisfied: lit in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from triton==2.0.0->torch>=1.6.0->kornia==0.5.0) (16.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from jinja2->torch>=1.6.0->kornia==0.5.0) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from sympy->torch>=1.6.0->kornia==0.5.0) (1.3.0)
# Installing collected packages: kornia
# Successfully installed kornia-0.5.0
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com, https://pypi.ngc.nvidia.com
# Collecting webdataset
#   Downloading webdataset-0.2.48-py3-none-any.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.9/51.9 kB 6.5 MB/s eta 0:00:00
# Collecting braceexpand (from webdataset)
#   Downloading braceexpand-0.1.7-py2.py3-none-any.whl (5.9 kB)
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from webdataset) (1.23.5)
# Requirement already satisfied: pyyaml in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from webdataset) (6.0)
# Installing collected packages: braceexpand, webdataset
# Successfully installed braceexpand-0.1.7 webdataset-0.2.48
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com, https://pypi.ngc.nvidia.com
# Requirement already satisfied: packaging in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (23.1)
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com, https://pypi.ngc.nvidia.com
# Requirement already satisfied: omegaconf==2.1.2 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (2.1.2)
# Requirement already satisfied: antlr4-python3-runtime==4.8 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from omegaconf==2.1.2) (4.8)
# Requirement already satisfied: PyYAML>=5.1.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from omegaconf==2.1.2) (6.0)
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com, https://pypi.ngc.nvidia.com
# Collecting torchvision
#   Downloading torchvision-0.15.2-cp38-cp38-manylinux1_x86_64.whl (33.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.8/33.8 MB 317.0 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torchvision) (1.23.5)
# Requirement already satisfied: requests in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torchvision) (2.30.0)
# Requirement already satisfied: torch==2.0.1 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torchvision) (2.0.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torchvision) (9.5.0)
# Requirement already satisfied: filelock in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch==2.0.1->torchvision) (3.12.0)
# Requirement already satisfied: typing-extensions in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch==2.0.1->torchvision) (4.5.0)
# Requirement already satisfied: sympy in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch==2.0.1->torchvision) (1.12)
# Requirement already satisfied: networkx in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch==2.0.1->torchvision) (3.1)
# Requirement already satisfied: jinja2 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch==2.0.1->torchvision) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch==2.0.1->torchvision) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch==2.0.1->torchvision) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch==2.0.1->torchvision) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch==2.0.1->torchvision) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch==2.0.1->torchvision) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch==2.0.1->torchvision) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch==2.0.1->torchvision) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch==2.0.1->torchvision) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch==2.0.1->torchvision) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch==2.0.1->torchvision) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch==2.0.1->torchvision) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch==2.0.1->torchvision) (2.0.0)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1->torchvision) (67.7.2)
# Requirement already satisfied: wheel in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1->torchvision) (0.40.0)
# Requirement already satisfied: cmake in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from triton==2.0.0->torch==2.0.1->torchvision) (3.26.3)
# Requirement already satisfied: lit in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from triton==2.0.0->torch==2.0.1->torchvision) (16.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from requests->torchvision) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from requests->torchvision) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from requests->torchvision) (2023.5.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from jinja2->torch==2.0.1->torchvision) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from sympy->torch==2.0.1->torchvision) (1.3.0)
# Installing collected packages: torchvision
# Successfully installed torchvision-0.15.2
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com, https://pypi.ngc.nvidia.com
# Collecting conda-pack
#   Downloading conda-pack-0.6.0.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 3.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from conda-pack) (67.7.2)
# Building wheels for collected packages: conda-pack
#   Building wheel for conda-pack (setup.py) ... done
#   Created wheel for conda-pack: filename=conda_pack-0.6.0-py2.py3-none-any.whl size=30883 sha256=e1ae3a87cdf912676ba8f15803a45fba12f56d3a44d41a9f4d585df5f9e4ad3a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-eshns9y_/wheels/56/1b/9e/0da27a4c18349d8f048a8fe87d763d75d3098384e9fa285e45
# Successfully built conda-pack
# Installing collected packages: conda-pack
# Successfully installed conda-pack-0.6.0
# Collecting packages...
# Packing environment at '/home/ec2-user/anaconda3/envs/lama_env' to 'lama_env.tar.gz'
# [########################################] | 100% Completed |  3min 42.8s

# %% [markdown]
# ### Extend SageMaker Managed Triton Container
#
# When we host these models on SageMaker MME. When invoked, model files will be loaded from S3 onto the instance. Due the large size of our models and model packages (SAM: 2.4GB + conda pack: 2.52 GB, LaMa: 0.38 GB + conda pack: 3.35GB), we are going to pre-load these files into the container. This will reduce model loading time and improve user experience during cold start.

# %%
# account mapping for SageMaker Triton Image
account_id_map = {
    "us-east-1": "785573368785",
    "us-east-2": "007439368137",
    "us-west-1": "710691900526",
    "us-west-2": "301217895009",
    "eu-west-1": "802834080501",
    "eu-west-2": "205493899709",
    "eu-west-3": "254080097072",
    "eu-north-1": "601324751636",
    "eu-south-1": "966458181534",
    "eu-central-1": "746233611703",
    "ap-east-1": "110948597952",
    "ap-south-1": "763008648453",
    "ap-northeast-1": "941853720454",
    "ap-northeast-2": "151534178276",
    "ap-southeast-1": "324986816169",
    "ap-southeast-2": "355873309152",
    "cn-northwest-1": "474822919863",
    "cn-north-1": "472730292857",
    "sa-east-1": "756306329178",
    "ca-central-1": "464438896020",
    "me-south-1": "836785723513",
    "af-south-1": "774647643957",
}



region = boto3.Session().region_name
if region not in account_id_map.keys():
    raise ("UNSUPPORTED REGION")

base = "amazonaws.com.cn" if region.startswith("cn-") else "amazonaws.com"
mme_triton_image_uri = (
    "{account_id}.dkr.ecr.{region}.{base}/sagemaker-tritonserver:22.12-py3".format(
        account_id=account_id_map[region], region=region, base=base
    )
)
triton_account_id = account_id_map[region]
mme_triton_image_uri
# Out:
# '301217895009.dkr.ecr.us-west-2.amazonaws.com/sagemaker-tritonserver:22.12-py3'

# %% [markdown]
# Preview the docker file

# %%
# !cat docker/Dockerfile
# Out:
# ARG BASE_IMAGE
#
# FROM $BASE_IMAGE
#
# #Install any additional libraries
# RUN echo "Adding conda package to Docker image"
# RUN mkdir -p /home/condpackenv/
# RUN mkdir -p /home/models/
#
# # Copy conda env
# COPY sam_env.tar.gz /home/condpackenv/sam_env.tar.gz
# COPY lama_env.tar.gz /home/condpackenv/lama_env.tar.gz
#
# COPY sam_vit_h_4b8939.pth.tar.gz /temp/
# COPY big-lama.tar.gz /temp/
#
# # Install tar
# RUN apt-get update && apt-get install -y tar
# RUN apt-get update && apt-get install ffmpeg libsm6 libxext6  -y
#
# # Untar the file
# RUN tar -xzf /temp/sam_vit_h_4b8939.pth.tar.gz -C /home/models/
# RUN tar -xzf /temp/big-lama.tar.gz -C /home/models/
#
# RUN rm /temp/sam_vit_h_4b8939.pth.tar.gz
# RUN rm /temp/big-lama.tar.gz

# %% [markdown]
# ### Build & push the new image to ECR

# %%
# New container image name
new_image_name = 'sagemaker-tritonserver-sam-lama'

# %%
# %%capture build_output
# !cd docker && bash build_and_push.sh "$new_image_name" "latest" "$mme_triton_image_uri" "$region" "$account" "$triton_account_id"

# %%
if 'Error response from daemon' in str(build_output):
    print(build_output)
    raise SystemExit('\n\n!!There was an error with the container build!!')
else:
    extended_triton_image_uri = str(build_output).strip().split('\n')[-1]
    
print(f"New image URI from ECR: {extended_triton_image_uri}")
# Out:
# New image URI from ECR: 376678947624.dkr.ecr.us-west-2.amazonaws.com/sagemaker-tritonserver-sam-lama:latest

# %%
# %store extended_triton_image_uri
# Out:
# Stored 'extended_triton_image_uri' (str)
