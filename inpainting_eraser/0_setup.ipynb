# %% [markdown]
# ## Setup for Inpainting Eraser Models
# ---
# In this notebook, you are going to run a defined setup process for our inpainting eraser solution. Due to the size of the models, some of the step may take some time to complete. The entire notebook should finish within 1 hour. At the end of the notebook run, we should have a instended inference container in Elastic Container Registry (ECR) ready to host our models using SageMaker Endpoint (MME).
#
# SageMaker MME is a service provided by Amazon SageMaker that allows multiple machine learning models to be hosted on a single endpoint. This means that multiple models can be deployed and managed together, making it easier to scale and maintain machine learning applications. With a multi-model endpoint, different models can be selected based on specific needs, allowing for more flexibility and efficiency. It also enables different types of models to be combined, such as computer vision and natural language processing models, to create more comprehensive applications.
#
# Here is a high level breakdown of the setup steps:
#
# 1. Downloading pre-trained models
# 2. Package conda environment for additional model dependencies
# 3. Extend SageMaker managed Triton container with model checkpoints and conda packs pre-loaded
# 4. Push the container to AWS Elastic Container Registry (ECR)
#
# ---
#
# This notebook will locally build a custom docker image. **We recommend to use pytorch kernel on SageMaker Notebook Instance using `ml.g4dn.xlarge`**

# %%
# !pip install -Uq sagemaker

# %% [markdown]
# ### Setup

# %%
import sagemaker
import boto3

import tarfile
import os

sagemaker_session = sagemaker.Session(boto_session=boto3.Session())
region = sagemaker_session.boto_region_name
account = sagemaker_session.account_id()

# %% [markdown]
# ### Download Pre-trained Models

# %% [markdown]
# #### Download and Package SAM Checkpoint
# **Apache-2.0 license**

# %%
model_file_name = "sam_vit_h_4b8939.pth"
download_path = f"https://huggingface.co/spaces/abhishek/StableSAM/resolve/main/{model_file_name}"

# !wget $download_path
# Out:
# --2024-01-17 03:54:42--  https://huggingface.co/spaces/abhishek/StableSAM/resolve/main/sam_vit_h_4b8939.pth
# Resolving huggingface.co (huggingface.co)... 99.84.66.65, 99.84.66.70, 99.84.66.112, ...
# Connecting to huggingface.co (huggingface.co)|99.84.66.65|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.huggingface.co/repos/47/d3/47d331d77ce5639cc128df17410f4744b11342191e8442f5cde65f20735d01f9/a7bf3b02f3ebf1267aba913ff637d9a2d5c33d3173bb679e46d9f338c26f262e?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27sam_vit_h_4b8939.pth%3B+filename%3D%22sam_vit_h_4b8939.pth%22%3B&Expires=1705722882&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=AiZG2Mb482Uz7mnIqSKd1Kzpgo5ZPTpSL606IeWcDErebrUxshkjOthXlDma0d61ectMnLsk-%7EK8uzmBpN4CFsAoEjfjCyl4aCMGwyzUkQn13v-k1ZQ--DKWvmRZlPpAWh6MKdDj4ShXnFXLpl00jagOzZ9A6dGJzYuDd7CuHSjQ6wGiI0G9kPjlTwu1L9Kj%7EvZL6k0ecezZPMqmAo14ZyWEOEtrgA9jgZVxU2vBGr3iHsclrS-W4GOV1hqRaTe9K1Vd%7EjSGqtnyJE812F30jLp%7El8fNBrFLzcYEYLsBLeuesyfDu4u%7EQL0OOLqh6qUbImGma7V%7Eae0XbJTyMOcABg__&Key-Pair-Id=KVTP0A1DKRTAX [following]
# --2024-01-17 03:54:42--  https://cdn-lfs.huggingface.co/repos/47/d3/47d331d77ce5639cc128df17410f4744b11342191e8442f5cde65f20735d01f9/a7bf3b02f3ebf1267aba913ff637d9a2d5c33d3173bb679e46d9f338c26f262e?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27sam_vit_h_4b8939.pth%3B+filename%3D%22sam_vit_h_4b8939.pth%22%3B&Expires=1705722882&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=AiZG2Mb482Uz7mnIqSKd1Kzpgo5ZPTpSL606IeWcDErebrUxshkjOthXlDma0d61ectMnLsk-%7EK8uzmBpN4CFsAoEjfjCyl4aCMGwyzUkQn13v-k1ZQ--DKWvmRZlPpAWh6MKdDj4ShXnFXLpl00jagOzZ9A6dGJzYuDd7CuHSjQ6wGiI0G9kPjlTwu1L9Kj%7EvZL6k0ecezZPMqmAo14ZyWEOEtrgA9jgZVxU2vBGr3iHsclrS-W4GOV1hqRaTe9K1Vd%7EjSGqtnyJE812F30jLp%7El8fNBrFLzcYEYLsBLeuesyfDu4u%7EQL0OOLqh6qUbImGma7V%7Eae0XbJTyMOcABg__&Key-Pair-Id=KVTP0A1DKRTAX
# Resolving cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)... 3.163.24.31, 3.163.24.30, 3.163.24.32, ...
# Connecting to cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)|3.163.24.31|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2564550879 (2.4G) [application/zip]
# Saving to: ‘sam_vit_h_4b8939.pth.1’
#
# 100%[====================================>] 2,564,550,879  413MB/s   in 6.2s
#
# 2024-01-17 03:54:48 (393 MB/s) - ‘sam_vit_h_4b8939.pth.1’ saved [2564550879/2564550879]

# %%
sd_tar = f"docker/{model_file_name}.tar.gz"

def make_tarfile(output_filename, source_dir):
    with tarfile.open(output_filename, "w:gz") as tar:
        tar.add(source_dir, arcname=os.path.basename(source_dir))

make_tarfile(sd_tar, model_file_name)

# %% [markdown]
# ### Download and Package LaMa Checkpoint
# **Apache-2.0 license**

# %%
# !wget https://huggingface.co/smartywu/big-lama/resolve/main/big-lama.zip
# !unzip big-lama.zip
# Out:
# --2024-01-17 03:56:35--  https://huggingface.co/smartywu/big-lama/resolve/main/big-lama.zip
# Resolving huggingface.co (huggingface.co)... 99.84.66.70, 99.84.66.112, 99.84.66.72, ...
# Connecting to huggingface.co (huggingface.co)|99.84.66.70|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.huggingface.co/repos/51/45/51456bfbae988f737d159c165ee79a3168fdd10d70db51da3e2dcc0cb29aa7a5/f1b358ca24093b93a106183b98a3dea6e8ed09f3b43ea7251eb2c81e7b4575f6?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27big-lama.zip%3B+filename%3D%22big-lama.zip%22%3B&response-content-type=application%2Fzip&Expires=1705722995&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qJnJlc3BvbnNlLWNvbnRlbnQtdHlwZT0qIn1dfQ__&Signature=R4DnutQclN5Xl5OUByNKGMWd1S9JOcs-YpGumW8AUe1oLIA0GUbO29-mMqCxkM2eyN5TODH56RIVmohFNHc11cydqKP5eQJ6xwjjctQm6guHhFa%7EKZcB60ZUC9kZKV3Uv3JSsVk2hzDDa0NtIIt%7EDNtMsHAcioIfFTpJaTfU-wXMiwfhXgS4c2IKgyHbB4HH0TnVmUfvdzl-TLytkvHXTbnA75SZLhPmZNOi1tUDk2t3Bn-ed%7EX3YW1eLYNMmlqEi11ierld7gxmdcjbHj4BGPCsVxvTfHsCcRrdKSl99TPj93vFiMpKKrnqLl4GIixRgXQuZVmH510InLkDQkIscw__&Key-Pair-Id=KVTP0A1DKRTAX [following]
# --2024-01-17 03:56:35--  https://cdn-lfs.huggingface.co/repos/51/45/51456bfbae988f737d159c165ee79a3168fdd10d70db51da3e2dcc0cb29aa7a5/f1b358ca24093b93a106183b98a3dea6e8ed09f3b43ea7251eb2c81e7b4575f6?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27big-lama.zip%3B+filename%3D%22big-lama.zip%22%3B&response-content-type=application%2Fzip&Expires=1705722995&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qJnJlc3BvbnNlLWNvbnRlbnQtdHlwZT0qIn1dfQ__&Signature=R4DnutQclN5Xl5OUByNKGMWd1S9JOcs-YpGumW8AUe1oLIA0GUbO29-mMqCxkM2eyN5TODH56RIVmohFNHc11cydqKP5eQJ6xwjjctQm6guHhFa%7EKZcB60ZUC9kZKV3Uv3JSsVk2hzDDa0NtIIt%7EDNtMsHAcioIfFTpJaTfU-wXMiwfhXgS4c2IKgyHbB4HH0TnVmUfvdzl-TLytkvHXTbnA75SZLhPmZNOi1tUDk2t3Bn-ed%7EX3YW1eLYNMmlqEi11ierld7gxmdcjbHj4BGPCsVxvTfHsCcRrdKSl99TPj93vFiMpKKrnqLl4GIixRgXQuZVmH510InLkDQkIscw__&Key-Pair-Id=KVTP0A1DKRTAX
# Resolving cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)... 3.163.24.30, 3.163.24.63, 3.163.24.31, ...
# Connecting to cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)|3.163.24.30|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 381428720 (364M) [application/zip]
# Saving to: ‘big-lama.zip.1’
#
# 100%[======================================>] 381,428,720  385MB/s   in 0.9s
#
# 2024-01-17 03:56:36 (385 MB/s) - ‘big-lama.zip.1’ saved [381428720/381428720]
#
# Archive:  big-lama.zip
# replace big-lama/config.yaml? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C

# %%
lama_dir = "big-lama"
lama_tar = f"docker/{lama_dir}.tar.gz"

def make_tarfile(output_filename, source_dir):
    with tarfile.open(output_filename, "w:gz") as tar:
        tar.add(source_dir, arcname=os.path.basename(source_dir))

make_tarfile(lama_tar, lama_dir)

# %% [markdown]
# LaMa needs additional source code script. We will clone the repo into our `model_repo` folder

# %%
# !cd model_repo/lama/1 && git clone https://github.com/advimman/lama.git
# Out:
# fatal: destination path 'lama' already exists and is not an empty directory.

# %% [markdown]
# #### Downloading Images and Modules from Inpaint Anything
# **Apache-2.0 license**

# %%
# !cd statics && wget https://raw.githubusercontent.com/geekyutao/Inpaint-Anything/main/example/fill-anything/sample1.png
# !cd statics && wget https://raw.githubusercontent.com/geekyutao/Inpaint-Anything/main/example/remove-anything/dog.jpg
# Out:
# --2024-01-17 04:25:06--  https://raw.githubusercontent.com/geekyutao/Inpaint-Anything/main/example/fill-anything/sample1.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2358157 (2.2M) [image/png]
# Saving to: ‘sample1.png.1’
#
# 100%[======================================>] 2,358,157   --.-K/s   in 0.05s
#
# 2024-01-17 04:25:06 (41.4 MB/s) - ‘sample1.png.1’ saved [2358157/2358157]
#
# --2024-01-17 04:25:06--  https://raw.githubusercontent.com/geekyutao/Inpaint-Anything/main/example/remove-anything/dog.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 99846 (98K) [image/jpeg]
# Saving to: ‘dog.jpg.1’
#
# 100%[======================================>] 99,846      --.-K/s   in 0.02s
#
# 2024-01-17 04:25:06 (6.32 MB/s) - ‘dog.jpg.1’ saved [99846/99846]

# %% [markdown]
# ### Package Conda Environment for each model
#
# SageMaker NVIDIA Triton container images does not contain all the libraries two run our SAM and LaMa models. However, Triton allows you to bring additional dependencies using conda pack. Let's run the two cells below to create a `xxx_env.tar.gz` environment package for each model.

# %%
# !cd docker && bash sam_conda_dependencies.sh
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.3.1
#   latest version: 23.11.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.11.0
#
#
#
# ## Package Plan ##
#
#   environment location: /home/ec2-user/anaconda3/envs/sam_env
#
#   added / updated specs:
#     - python=3.8
#
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      conda-forge/linux-64::_libgcc_mutex-0.1-conda_forge
#   _openmp_mutex      conda-forge/linux-64::_openmp_mutex-4.5-2_gnu
#   bzip2              conda-forge/linux-64::bzip2-1.0.8-hd590300_5
#   ca-certificates    conda-forge/linux-64::ca-certificates-2023.11.17-hbcca054_0
#   ld_impl_linux-64   conda-forge/linux-64::ld_impl_linux-64-2.40-h41732ed_0
#   libffi             conda-forge/linux-64::libffi-3.4.2-h7f98852_5
#   libgcc-ng          conda-forge/linux-64::libgcc-ng-13.2.0-h807b86a_3
#   libgomp            conda-forge/linux-64::libgomp-13.2.0-h807b86a_3
#   libnsl             conda-forge/linux-64::libnsl-2.0.1-hd590300_0
#   libsqlite          conda-forge/linux-64::libsqlite-3.44.2-h2797004_0
#   libuuid            conda-forge/linux-64::libuuid-2.38.1-h0b41bf4_0
#   libxcrypt          conda-forge/linux-64::libxcrypt-4.4.36-hd590300_1
#   libzlib            conda-forge/linux-64::libzlib-1.2.13-hd590300_5
#   ncurses            conda-forge/linux-64::ncurses-6.4-h59595ed_2
#   openssl            conda-forge/linux-64::openssl-3.2.0-hd590300_1
#   pip                conda-forge/noarch::pip-23.3.2-pyhd8ed1ab_0
#   python             conda-forge/linux-64::python-3.8.18-hd12c33a_1_cpython
#   readline           conda-forge/linux-64::readline-8.2-h8228510_1
#   setuptools         conda-forge/noarch::setuptools-69.0.3-pyhd8ed1ab_0
#   tk                 conda-forge/linux-64::tk-8.6.13-noxft_h4845f30_101
#   wheel              conda-forge/noarch::wheel-0.42.0-pyhd8ed1ab_0
#   xz                 conda-forge/linux-64::xz-5.2.6-h166bdaf_0
#
#
#
# Downloading and Extracting Packages
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# #
# # To activate this environment, use
# #
# #     $ conda activate sam_env
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu118
# Collecting torch
#   Using cached https://download.pytorch.org/whl/cu118/torch-2.1.2%2Bcu118-cp38-cp38-linux_x86_64.whl (2325.9 MB)
# Collecting filelock (from torch)
#   Using cached filelock-3.13.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting typing-extensions (from torch)
#   Using cached typing_extensions-4.9.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting sympy (from torch)
#   Using cached https://download.pytorch.org/whl/sympy-1.12-py3-none-any.whl (5.7 MB)
# Collecting networkx (from torch)
#   Using cached networkx-3.1-py3-none-any.whl (2.1 MB)
# Collecting jinja2 (from torch)
#   Using cached Jinja2-3.1.3-py3-none-any.whl.metadata (3.3 kB)
# Collecting fsspec (from torch)
#   Using cached fsspec-2023.12.2-py3-none-any.whl.metadata (6.8 kB)
# Collecting triton==2.1.0 (from torch)
#   Using cached https://download.pytorch.org/whl/triton-2.1.0-0-cp38-cp38-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89.2 MB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Using cached https://download.pytorch.org/whl/MarkupSafe-2.1.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Collecting mpmath>=0.19 (from sympy->torch)
#   Using cached https://download.pytorch.org/whl/mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached filelock-3.13.1-py3-none-any.whl (11 kB)
# Using cached fsspec-2023.12.2-py3-none-any.whl (168 kB)
# Using cached Jinja2-3.1.3-py3-none-any.whl (133 kB)
# Using cached typing_extensions-4.9.0-py3-none-any.whl (32 kB)
# Installing collected packages: mpmath, typing-extensions, sympy, networkx, MarkupSafe, fsspec, filelock, triton, jinja2, torch
# Successfully installed MarkupSafe-2.1.3 filelock-3.13.1 fsspec-2023.12.2 jinja2-3.1.3 mpmath-1.3.0 networkx-3.1 sympy-1.12 torch-2.1.2+cu118 triton-2.1.0 typing-extensions-4.9.0
# Collecting segment-anything-py==1.0
#   Using cached segment_anything_py-1.0-py3-none-any.whl (40 kB)
# Requirement already satisfied: torch>=1.7 in /home/ec2-user/anaconda3/envs/sam_env/lib/python3.8/site-packages (from segment-anything-py==1.0) (2.1.2+cu118)
# Collecting torchvision>=0.8 (from segment-anything-py==1.0)
#   Using cached torchvision-0.16.2-cp38-cp38-manylinux1_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: filelock in /home/ec2-user/anaconda3/envs/sam_env/lib/python3.8/site-packages (from torch>=1.7->segment-anything-py==1.0) (3.13.1)
# Requirement already satisfied: typing-extensions in /home/ec2-user/anaconda3/envs/sam_env/lib/python3.8/site-packages (from torch>=1.7->segment-anything-py==1.0) (4.9.0)
# Requirement already satisfied: sympy in /home/ec2-user/anaconda3/envs/sam_env/lib/python3.8/site-packages (from torch>=1.7->segment-anything-py==1.0) (1.12)
# Requirement already satisfied: networkx in /home/ec2-user/anaconda3/envs/sam_env/lib/python3.8/site-packages (from torch>=1.7->segment-anything-py==1.0) (3.1)
# Requirement already satisfied: jinja2 in /home/ec2-user/anaconda3/envs/sam_env/lib/python3.8/site-packages (from torch>=1.7->segment-anything-py==1.0) (3.1.3)
# Requirement already satisfied: fsspec in /home/ec2-user/anaconda3/envs/sam_env/lib/python3.8/site-packages (from torch>=1.7->segment-anything-py==1.0) (2023.12.2)
# Requirement already satisfied: triton==2.1.0 in /home/ec2-user/anaconda3/envs/sam_env/lib/python3.8/site-packages (from torch>=1.7->segment-anything-py==1.0) (2.1.0)
# Collecting numpy (from torchvision>=0.8->segment-anything-py==1.0)
#   Using cached numpy-1.24.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Collecting requests (from torchvision>=0.8->segment-anything-py==1.0)
#   Using cached requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting pillow!=8.3.*,>=5.3.0 (from torchvision>=0.8->segment-anything-py==1.0)
#   Using cached pillow-10.2.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.7 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ec2-user/anaconda3/envs/sam_env/lib/python3.8/site-packages (from jinja2->torch>=1.7->segment-anything-py==1.0) (2.1.3)
# Collecting charset-normalizer<4,>=2 (from requests->torchvision>=0.8->segment-anything-py==1.0)
#   Using cached charset_normalizer-3.3.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (33 kB)
# Collecting idna<4,>=2.5 (from requests->torchvision>=0.8->segment-anything-py==1.0)
#   Using cached idna-3.6-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->torchvision>=0.8->segment-anything-py==1.0)
#   Using cached urllib3-2.1.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests->torchvision>=0.8->segment-anything-py==1.0)
#   Using cached certifi-2023.11.17-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: mpmath>=0.19 in /home/ec2-user/anaconda3/envs/sam_env/lib/python3.8/site-packages (from sympy->torch>=1.7->segment-anything-py==1.0) (1.3.0)
# Using cached torchvision-0.16.2-cp38-cp38-manylinux1_x86_64.whl (6.8 MB)
# Using cached pillow-10.2.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.4 MB)
# Using cached numpy-1.24.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
# Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Using cached certifi-2023.11.17-py3-none-any.whl (162 kB)
# Using cached charset_normalizer-3.3.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
# Using cached idna-3.6-py3-none-any.whl (61 kB)
# Using cached urllib3-2.1.0-py3-none-any.whl (104 kB)
# Installing collected packages: urllib3, pillow, numpy, idna, charset-normalizer, certifi, requests, torchvision, segment-anything-py
# Successfully installed certifi-2023.11.17 charset-normalizer-3.3.2 idna-3.6 numpy-1.24.4 pillow-10.2.0 requests-2.31.0 segment-anything-py-1.0 torchvision-0.16.2 urllib3-2.1.0
# Collecting opencv-python-headless==4.7.0.68
#   Using cached opencv_python_headless-4.7.0.68-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.2 MB)
# Requirement already satisfied: numpy>=1.17.0 in /home/ec2-user/anaconda3/envs/sam_env/lib/python3.8/site-packages (from opencv-python-headless==4.7.0.68) (1.24.4)
# Installing collected packages: opencv-python-headless
# Successfully installed opencv-python-headless-4.7.0.68
# Collecting matplotlib==3.6.3
#   Using cached matplotlib-3.6.3-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (9.4 MB)
# Collecting contourpy>=1.0.1 (from matplotlib==3.6.3)
#   Using cached contourpy-1.1.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.9 kB)
# Collecting cycler>=0.10 (from matplotlib==3.6.3)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib==3.6.3)
#   Using cached fonttools-4.47.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (157 kB)
# Collecting kiwisolver>=1.0.1 (from matplotlib==3.6.3)
#   Using cached kiwisolver-1.4.5-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.19 in /home/ec2-user/anaconda3/envs/sam_env/lib/python3.8/site-packages (from matplotlib==3.6.3) (1.24.4)
# Collecting packaging>=20.0 (from matplotlib==3.6.3)
#   Using cached packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: pillow>=6.2.0 in /home/ec2-user/anaconda3/envs/sam_env/lib/python3.8/site-packages (from matplotlib==3.6.3) (10.2.0)
# Collecting pyparsing>=2.2.1 (from matplotlib==3.6.3)
#   Using cached pyparsing-3.1.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting python-dateutil>=2.7 (from matplotlib==3.6.3)
#   Using cached python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
# Collecting six>=1.5 (from python-dateutil>=2.7->matplotlib==3.6.3)
#   Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Using cached contourpy-1.1.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (301 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.47.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
# Using cached kiwisolver-1.4.5-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.2 MB)
# Using cached packaging-23.2-py3-none-any.whl (53 kB)
# Using cached pyparsing-3.1.1-py3-none-any.whl (103 kB)
# Installing collected packages: six, pyparsing, packaging, kiwisolver, fonttools, cycler, contourpy, python-dateutil, matplotlib
# Successfully installed contourpy-1.1.1 cycler-0.12.1 fonttools-4.47.2 kiwisolver-1.4.5 matplotlib-3.6.3 packaging-23.2 pyparsing-3.1.1 python-dateutil-2.8.2 six-1.16.0
# Collecting conda-pack
#   Using cached conda_pack-0.7.1-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/sam_env/lib/python3.8/site-packages (from conda-pack) (69.0.3)
# Using cached conda_pack-0.7.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: conda-pack
# Successfully installed conda-pack-0.7.1
# Collecting packages...
# Packing environment at '/home/ec2-user/anaconda3/envs/sam_env' to 'sam_env.tar.gz'
# [########################################] | 100% Completed |  2min 58.9s

# %%
# !cd docker && bash lama_conda_dependencies.sh
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.3.1
#   latest version: 23.11.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.11.0
#
#
#
# ## Package Plan ##
#
#   environment location: /home/ec2-user/anaconda3/envs/lama_env
#
#   added / updated specs:
#     - python=3.8
#
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      conda-forge/linux-64::_libgcc_mutex-0.1-conda_forge
#   _openmp_mutex      conda-forge/linux-64::_openmp_mutex-4.5-2_gnu
#   bzip2              conda-forge/linux-64::bzip2-1.0.8-hd590300_5
#   ca-certificates    conda-forge/linux-64::ca-certificates-2023.11.17-hbcca054_0
#   ld_impl_linux-64   conda-forge/linux-64::ld_impl_linux-64-2.40-h41732ed_0
#   libffi             conda-forge/linux-64::libffi-3.4.2-h7f98852_5
#   libgcc-ng          conda-forge/linux-64::libgcc-ng-13.2.0-h807b86a_3
#   libgomp            conda-forge/linux-64::libgomp-13.2.0-h807b86a_3
#   libnsl             conda-forge/linux-64::libnsl-2.0.1-hd590300_0
#   libsqlite          conda-forge/linux-64::libsqlite-3.44.2-h2797004_0
#   libuuid            conda-forge/linux-64::libuuid-2.38.1-h0b41bf4_0
#   libxcrypt          conda-forge/linux-64::libxcrypt-4.4.36-hd590300_1
#   libzlib            conda-forge/linux-64::libzlib-1.2.13-hd590300_5
#   ncurses            conda-forge/linux-64::ncurses-6.4-h59595ed_2
#   openssl            conda-forge/linux-64::openssl-3.2.0-hd590300_1
#   pip                conda-forge/noarch::pip-23.3.2-pyhd8ed1ab_0
#   python             conda-forge/linux-64::python-3.8.18-hd12c33a_1_cpython
#   readline           conda-forge/linux-64::readline-8.2-h8228510_1
#   setuptools         conda-forge/noarch::setuptools-69.0.3-pyhd8ed1ab_0
#   tk                 conda-forge/linux-64::tk-8.6.13-noxft_h4845f30_101
#   wheel              conda-forge/noarch::wheel-0.42.0-pyhd8ed1ab_0
#   xz                 conda-forge/linux-64::xz-5.2.6-h166bdaf_0
#
#
#
# Downloading and Extracting Packages
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# #
# # To activate this environment, use
# #
# #     $ conda activate lama_env
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu118
# Collecting torch
#   Using cached https://download.pytorch.org/whl/cu118/torch-2.1.2%2Bcu118-cp38-cp38-linux_x86_64.whl (2325.9 MB)
# Collecting filelock (from torch)
#   Using cached filelock-3.13.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting typing-extensions (from torch)
#   Using cached typing_extensions-4.9.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting sympy (from torch)
#   Using cached https://download.pytorch.org/whl/sympy-1.12-py3-none-any.whl (5.7 MB)
# Collecting networkx (from torch)
#   Using cached networkx-3.1-py3-none-any.whl (2.1 MB)
# Collecting jinja2 (from torch)
#   Using cached Jinja2-3.1.3-py3-none-any.whl.metadata (3.3 kB)
# Collecting fsspec (from torch)
#   Using cached fsspec-2023.12.2-py3-none-any.whl.metadata (6.8 kB)
# Collecting triton==2.1.0 (from torch)
#   Using cached https://download.pytorch.org/whl/triton-2.1.0-0-cp38-cp38-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89.2 MB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Using cached https://download.pytorch.org/whl/MarkupSafe-2.1.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Collecting mpmath>=0.19 (from sympy->torch)
#   Using cached https://download.pytorch.org/whl/mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached filelock-3.13.1-py3-none-any.whl (11 kB)
# Using cached fsspec-2023.12.2-py3-none-any.whl (168 kB)
# Using cached Jinja2-3.1.3-py3-none-any.whl (133 kB)
# Using cached typing_extensions-4.9.0-py3-none-any.whl (32 kB)
# Installing collected packages: mpmath, typing-extensions, sympy, networkx, MarkupSafe, fsspec, filelock, triton, jinja2, torch
# Successfully installed MarkupSafe-2.1.3 filelock-3.13.1 fsspec-2023.12.2 jinja2-3.1.3 mpmath-1.3.0 networkx-3.1 sympy-1.12 torch-2.1.2+cu118 triton-2.1.0 typing-extensions-4.9.0
# Collecting opencv-python
#   Using cached opencv_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting numpy>=1.17.0 (from opencv-python)
#   Using cached numpy-1.24.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Using cached opencv_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (62.2 MB)
# Using cached numpy-1.24.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
# Installing collected packages: numpy, opencv-python
# Successfully installed numpy-1.24.4 opencv-python-4.9.0.80
# Collecting pyyaml
#   Using cached PyYAML-6.0.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Using cached PyYAML-6.0.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (736 kB)
# Installing collected packages: pyyaml
# Successfully installed pyyaml-6.0.1
# Collecting tqdm
#   Using cached tqdm-4.66.1-py3-none-any.whl.metadata (57 kB)
# Using cached tqdm-4.66.1-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm
# Successfully installed tqdm-4.66.1
# Collecting numpy==1.23
#   Using cached numpy-1.23.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.4
#     Uninstalling numpy-1.24.4:
#       Successfully uninstalled numpy-1.24.4
# Successfully installed numpy-1.23.0
# Collecting easydict==1.9.0
#   Using cached easydict-1.9-py3-none-any.whl
# Installing collected packages: easydict
# Successfully installed easydict-1.9
# Collecting scikit-image==0.17.2
#   Using cached scikit_image-0.17.2-cp38-cp38-manylinux1_x86_64.whl (12.4 MB)
# Requirement already satisfied: numpy>=1.15.1 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from scikit-image==0.17.2) (1.23.0)
# Collecting scipy>=1.0.1 (from scikit-image==0.17.2)
#   Using cached scipy-1.10.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.5 MB)
# Collecting matplotlib!=3.0.0,>=2.0.0 (from scikit-image==0.17.2)
#   Using cached matplotlib-3.7.4-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (5.7 kB)
# Requirement already satisfied: networkx>=2.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from scikit-image==0.17.2) (3.1)
# Collecting pillow!=7.1.0,!=7.1.1,>=4.3.0 (from scikit-image==0.17.2)
#   Using cached pillow-10.2.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.7 kB)
# Collecting imageio>=2.3.0 (from scikit-image==0.17.2)
#   Using cached imageio-2.33.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting tifffile>=2019.7.26 (from scikit-image==0.17.2)
#   Using cached tifffile-2023.7.10-py3-none-any.whl.metadata (31 kB)
# Collecting PyWavelets>=1.1.1 (from scikit-image==0.17.2)
#   Using cached PyWavelets-1.4.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.9 MB)
# Collecting contourpy>=1.0.1 (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.17.2)
#   Using cached contourpy-1.1.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.9 kB)
# Collecting cycler>=0.10 (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.17.2)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.17.2)
#   Using cached fonttools-4.47.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (157 kB)
# Collecting kiwisolver>=1.0.1 (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.17.2)
#   Using cached kiwisolver-1.4.5-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (6.4 kB)
# Collecting packaging>=20.0 (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.17.2)
#   Using cached packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.17.2)
#   Using cached pyparsing-3.1.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting python-dateutil>=2.7 (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.17.2)
#   Using cached python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
# Collecting importlib-resources>=3.2.0 (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.17.2)
#   Using cached importlib_resources-6.1.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting zipp>=3.1.0 (from importlib-resources>=3.2.0->matplotlib!=3.0.0,>=2.0.0->scikit-image==0.17.2)
#   Using cached zipp-3.17.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting six>=1.5 (from python-dateutil>=2.7->matplotlib!=3.0.0,>=2.0.0->scikit-image==0.17.2)
#   Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Using cached imageio-2.33.1-py3-none-any.whl (313 kB)
# Using cached matplotlib-3.7.4-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (9.2 MB)
# Using cached pillow-10.2.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.4 MB)
# Using cached tifffile-2023.7.10-py3-none-any.whl (220 kB)
# Using cached contourpy-1.1.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (301 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.47.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
# Using cached importlib_resources-6.1.1-py3-none-any.whl (33 kB)
# Using cached kiwisolver-1.4.5-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.2 MB)
# Using cached packaging-23.2-py3-none-any.whl (53 kB)
# Using cached pyparsing-3.1.1-py3-none-any.whl (103 kB)
# Using cached zipp-3.17.0-py3-none-any.whl (7.4 kB)
# Installing collected packages: zipp, tifffile, six, scipy, PyWavelets, pyparsing, pillow, packaging, kiwisolver, fonttools, cycler, contourpy, python-dateutil, importlib-resources, imageio, matplotlib, scikit-image
# Successfully installed PyWavelets-1.4.1 contourpy-1.1.1 cycler-0.12.1 fonttools-4.47.2 imageio-2.33.1 importlib-resources-6.1.1 kiwisolver-1.4.5 matplotlib-3.7.4 packaging-23.2 pillow-10.2.0 pyparsing-3.1.1 python-dateutil-2.8.2 scikit-image-0.17.2 scipy-1.10.1 six-1.16.0 tifffile-2023.7.10 zipp-3.17.0
# Collecting scikit-learn==0.24.2
#   Using cached scikit_learn-0.24.2-cp38-cp38-manylinux2010_x86_64.whl (24.9 MB)
# Requirement already satisfied: numpy>=1.13.3 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from scikit-learn==0.24.2) (1.23.0)
# Requirement already satisfied: scipy>=0.19.1 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from scikit-learn==0.24.2) (1.10.1)
# Collecting joblib>=0.11 (from scikit-learn==0.24.2)
#   Using cached joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn==0.24.2)
#   Using cached threadpoolctl-3.2.0-py3-none-any.whl.metadata (10.0 kB)
# Using cached joblib-1.3.2-py3-none-any.whl (302 kB)
# Using cached threadpoolctl-3.2.0-py3-none-any.whl (15 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
# Successfully installed joblib-1.3.2 scikit-learn-0.24.2 threadpoolctl-3.2.0
# Collecting tensorflow
#   Using cached tensorflow-2.13.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Collecting absl-py>=1.0.0 (from tensorflow)
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting flatbuffers>=23.1.21 (from tensorflow)
#   Using cached flatbuffers-23.5.26-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting gast<=0.4.0,>=0.2.1 (from tensorflow)
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow)
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow)
#   Using cached grpcio-1.60.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting h5py>=2.9.0 (from tensorflow)
#   Using cached h5py-3.10.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.5 kB)
# Collecting keras<2.14,>=2.13.1 (from tensorflow)
#   Using cached keras-2.13.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Using cached libclang-16.0.6-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from tensorflow) (1.23.0)
# Collecting opt-einsum>=2.3.2 (from tensorflow)
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Requirement already satisfied: packaging in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from tensorflow) (23.2)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow)
#   Using cached protobuf-4.25.2-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from tensorflow) (69.0.3)
# Requirement already satisfied: six>=1.12.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from tensorflow) (1.16.0)
# Collecting tensorboard<2.14,>=2.13 (from tensorflow)
#   Using cached tensorboard-2.13.0-py3-none-any.whl (5.6 MB)
# Collecting tensorflow-estimator<2.14,>=2.13.0 (from tensorflow)
#   Using cached tensorflow_estimator-2.13.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Using cached termcolor-2.4.0-py3-none-any.whl.metadata (6.1 kB)
# Collecting typing-extensions<4.6.0,>=3.6.6 (from tensorflow)
#   Using cached typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Collecting wrapt>=1.11.0 (from tensorflow)
#   Using cached wrapt-1.16.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow)
#   Using cached tensorflow_io_gcs_filesystem-0.34.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from astunparse>=1.6.0->tensorflow) (0.42.0)
# Collecting google-auth<3,>=1.6.3 (from tensorboard<2.14,>=2.13->tensorflow)
#   Using cached google_auth-2.26.2-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting google-auth-oauthlib<1.1,>=0.5 (from tensorboard<2.14,>=2.13->tensorflow)
#   Using cached google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Collecting markdown>=2.6.8 (from tensorboard<2.14,>=2.13->tensorflow)
#   Using cached Markdown-3.5.2-py3-none-any.whl.metadata (7.0 kB)
# Collecting requests<3,>=2.21.0 (from tensorboard<2.14,>=2.13->tensorflow)
#   Using cached requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.14,>=2.13->tensorflow)
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard<2.14,>=2.13->tensorflow)
#   Using cached werkzeug-3.0.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow)
#   Using cached cachetools-5.3.2-py3-none-any.whl.metadata (5.2 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow)
#   Using cached pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow)
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow)
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting importlib-metadata>=4.4 (from markdown>=2.6.8->tensorboard<2.14,>=2.13->tensorflow)
#   Using cached importlib_metadata-7.0.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting charset-normalizer<4,>=2 (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow)
#   Using cached charset_normalizer-3.3.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (33 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow)
#   Using cached idna-3.6-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow)
#   Using cached urllib3-2.1.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow)
#   Using cached certifi-2023.11.17-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow) (2.1.3)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.14,>=2.13->tensorflow) (3.17.0)
# Collecting pyasn1<0.6.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow)
#   Using cached pyasn1-0.5.1-py2.py3-none-any.whl.metadata (8.6 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow)
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Using cached tensorflow-2.13.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (479.6 MB)
# Using cached absl_py-2.1.0-py3-none-any.whl (133 kB)
# Using cached flatbuffers-23.5.26-py2.py3-none-any.whl (26 kB)
# Using cached grpcio-1.60.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
# Using cached h5py-3.10.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
# Using cached keras-2.13.1-py3-none-any.whl (1.7 MB)
# Using cached libclang-16.0.6-py2.py3-none-manylinux2010_x86_64.whl (22.9 MB)
# Using cached protobuf-4.25.2-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
# Using cached tensorflow_estimator-2.13.0-py2.py3-none-any.whl (440 kB)
# Using cached tensorflow_io_gcs_filesystem-0.34.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.4 MB)
# Using cached termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Using cached wrapt-1.16.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (83 kB)
# Using cached google_auth-2.26.2-py2.py3-none-any.whl (186 kB)
# Using cached Markdown-3.5.2-py3-none-any.whl (103 kB)
# Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Using cached tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Using cached werkzeug-3.0.1-py3-none-any.whl (226 kB)
# Using cached cachetools-5.3.2-py3-none-any.whl (9.3 kB)
# Using cached certifi-2023.11.17-py3-none-any.whl (162 kB)
# Using cached charset_normalizer-3.3.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
# Using cached idna-3.6-py3-none-any.whl (61 kB)
# Using cached importlib_metadata-7.0.1-py3-none-any.whl (23 kB)
# Using cached urllib3-2.1.0-py3-none-any.whl (104 kB)
# Using cached pyasn1-0.5.1-py2.py3-none-any.whl (84 kB)
# Installing collected packages: libclang, flatbuffers, wrapt, werkzeug, urllib3, typing-extensions, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, pyasn1, protobuf, opt-einsum, oauthlib, keras, importlib-metadata, idna, h5py, grpcio, google-pasta, gast, charset-normalizer, certifi, cachetools, astunparse, absl-py, rsa, requests, pyasn1-modules, markdown, requests-oauthlib, google-auth, google-auth-oauthlib, tensorboard, tensorflow
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.9.0
#     Uninstalling typing_extensions-4.9.0:
#       Successfully uninstalled typing_extensions-4.9.0
# Successfully installed absl-py-2.1.0 astunparse-1.6.3 cachetools-5.3.2 certifi-2023.11.17 charset-normalizer-3.3.2 flatbuffers-23.5.26 gast-0.4.0 google-auth-2.26.2 google-auth-oauthlib-1.0.0 google-pasta-0.2.0 grpcio-1.60.0 h5py-3.10.0 idna-3.6 importlib-metadata-7.0.1 keras-2.13.1 libclang-16.0.6 markdown-3.5.2 oauthlib-3.2.2 opt-einsum-3.3.0 protobuf-4.25.2 pyasn1-0.5.1 pyasn1-modules-0.3.0 requests-2.31.0 requests-oauthlib-1.3.1 rsa-4.9 tensorboard-2.13.0 tensorboard-data-server-0.7.2 tensorflow-2.13.1 tensorflow-estimator-2.13.0 tensorflow-io-gcs-filesystem-0.34.0 termcolor-2.4.0 typing-extensions-4.5.0 urllib3-2.1.0 werkzeug-3.0.1 wrapt-1.16.0
# Requirement already satisfied: joblib in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (1.3.2)
# Requirement already satisfied: matplotlib in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (3.7.4)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from matplotlib) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.20 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from matplotlib) (1.23.0)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from matplotlib) (6.1.1)
# Requirement already satisfied: zipp>=3.1.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.17.0)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Collecting pandas
#   Using cached pandas-2.0.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from pandas) (2.8.2)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2023.3.post1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.1 (from pandas)
#   Using cached tzdata-2023.4-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: numpy>=1.20.3 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from pandas) (1.23.0)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Using cached pandas-2.0.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
# Using cached pytz-2023.3.post1-py2.py3-none-any.whl (502 kB)
# Using cached tzdata-2023.4-py2.py3-none-any.whl (346 kB)
# Installing collected packages: pytz, tzdata, pandas
# Successfully installed pandas-2.0.3 pytz-2023.3.post1 tzdata-2023.4
# Collecting albumentations==0.5.2
#   Using cached albumentations-0.5.2-py3-none-any.whl (72 kB)
# Requirement already satisfied: numpy>=1.11.1 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from albumentations==0.5.2) (1.23.0)
# Requirement already satisfied: scipy in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from albumentations==0.5.2) (1.10.1)
# Requirement already satisfied: scikit-image>=0.16.1 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from albumentations==0.5.2) (0.17.2)
# Collecting imgaug>=0.4.0 (from albumentations==0.5.2)
#   Using cached imgaug-0.4.0-py2.py3-none-any.whl (948 kB)
# Requirement already satisfied: PyYAML in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from albumentations==0.5.2) (6.0.1)
# Collecting opencv-python-headless>=4.1.1 (from albumentations==0.5.2)
#   Using cached opencv_python_headless-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: six in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from imgaug>=0.4.0->albumentations==0.5.2) (1.16.0)
# Requirement already satisfied: Pillow in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from imgaug>=0.4.0->albumentations==0.5.2) (10.2.0)
# Requirement already satisfied: matplotlib in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from imgaug>=0.4.0->albumentations==0.5.2) (3.7.4)
# Requirement already satisfied: opencv-python in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from imgaug>=0.4.0->albumentations==0.5.2) (4.9.0.80)
# Requirement already satisfied: imageio in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from imgaug>=0.4.0->albumentations==0.5.2) (2.33.1)
# Collecting Shapely (from imgaug>=0.4.0->albumentations==0.5.2)
#   Using cached shapely-2.0.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.0 kB)
# Requirement already satisfied: networkx>=2.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from scikit-image>=0.16.1->albumentations==0.5.2) (3.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from scikit-image>=0.16.1->albumentations==0.5.2) (2023.7.10)
# Requirement already satisfied: PyWavelets>=1.1.1 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from scikit-image>=0.16.1->albumentations==0.5.2) (1.4.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from matplotlib->imgaug>=0.4.0->albumentations==0.5.2) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from matplotlib->imgaug>=0.4.0->albumentations==0.5.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from matplotlib->imgaug>=0.4.0->albumentations==0.5.2) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from matplotlib->imgaug>=0.4.0->albumentations==0.5.2) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from matplotlib->imgaug>=0.4.0->albumentations==0.5.2) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from matplotlib->imgaug>=0.4.0->albumentations==0.5.2) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from matplotlib->imgaug>=0.4.0->albumentations==0.5.2) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from matplotlib->imgaug>=0.4.0->albumentations==0.5.2) (6.1.1)
# Requirement already satisfied: zipp>=3.1.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib->imgaug>=0.4.0->albumentations==0.5.2) (3.17.0)
# Using cached opencv_python_headless-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.6 MB)
# Using cached shapely-2.0.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.5 MB)
# Installing collected packages: Shapely, opencv-python-headless, imgaug, albumentations
# Successfully installed Shapely-2.0.2 albumentations-0.5.2 imgaug-0.4.0 opencv-python-headless-4.9.0.80
# Collecting hydra-core==1.1.0
#   Using cached hydra_core-1.1.0-py3-none-any.whl (144 kB)
# Collecting omegaconf==2.1.* (from hydra-core==1.1.0)
#   Using cached omegaconf-2.1.2-py3-none-any.whl (74 kB)
# Collecting antlr4-python3-runtime==4.8 (from hydra-core==1.1.0)
#   Using cached antlr4_python3_runtime-4.8-py3-none-any.whl
# Requirement already satisfied: importlib-resources in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from hydra-core==1.1.0) (6.1.1)
# Requirement already satisfied: PyYAML>=5.1.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from omegaconf==2.1.*->hydra-core==1.1.0) (6.0.1)
# Requirement already satisfied: zipp>=3.1.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from importlib-resources->hydra-core==1.1.0) (3.17.0)
# Installing collected packages: antlr4-python3-runtime, omegaconf, hydra-core
# Successfully installed antlr4-python3-runtime-4.8 hydra-core-1.1.0 omegaconf-2.1.2
# Collecting pytorch-lightning==1.2.9
#   Using cached pytorch_lightning-1.2.9-py3-none-any.whl (841 kB)
# Requirement already satisfied: numpy>=1.16.6 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from pytorch-lightning==1.2.9) (1.23.0)
# Requirement already satisfied: torch>=1.4 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from pytorch-lightning==1.2.9) (2.1.2+cu118)
# Collecting future>=0.17.1 (from pytorch-lightning==1.2.9)
#   Using cached future-0.18.3-py3-none-any.whl
# Requirement already satisfied: PyYAML!=5.4.*,>=5.1 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from pytorch-lightning==1.2.9) (6.0.1)
# Requirement already satisfied: tqdm>=4.41.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from pytorch-lightning==1.2.9) (4.66.1)
# Requirement already satisfied: fsspec>=0.8.1 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from fsspec[http]>=0.8.1->pytorch-lightning==1.2.9) (2023.12.2)
# Requirement already satisfied: tensorboard!=2.5.0,>=2.2.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from pytorch-lightning==1.2.9) (2.13.0)
# Collecting torchmetrics==0.2.0 (from pytorch-lightning==1.2.9)
#   Using cached torchmetrics-0.2.0-py3-none-any.whl (176 kB)
# Requirement already satisfied: requests in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from fsspec[http]>=0.8.1->pytorch-lightning==1.2.9) (2.31.0)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]>=0.8.1->pytorch-lightning==1.2.9)
#   Using cached aiohttp-3.9.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.4 kB)
# Requirement already satisfied: absl-py>=0.4 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.9) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.9) (1.60.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.9) (2.26.2)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.9) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.9) (3.5.2)
# Requirement already satisfied: protobuf>=3.19.6 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.9) (4.25.2)
# Requirement already satisfied: setuptools>=41.0.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.9) (69.0.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.9) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.9) (3.0.1)
# Requirement already satisfied: wheel>=0.26 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.9) (0.42.0)
# Requirement already satisfied: filelock in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch>=1.4->pytorch-lightning==1.2.9) (3.13.1)
# Requirement already satisfied: typing-extensions in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch>=1.4->pytorch-lightning==1.2.9) (4.5.0)
# Requirement already satisfied: sympy in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch>=1.4->pytorch-lightning==1.2.9) (1.12)
# Requirement already satisfied: networkx in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch>=1.4->pytorch-lightning==1.2.9) (3.1)
# Requirement already satisfied: jinja2 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch>=1.4->pytorch-lightning==1.2.9) (3.1.3)
# Requirement already satisfied: triton==2.1.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch>=1.4->pytorch-lightning==1.2.9) (2.1.0)
# Collecting attrs>=17.3.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=0.8.1->pytorch-lightning==1.2.9)
#   Using cached attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=0.8.1->pytorch-lightning==1.2.9)
#   Using cached multidict-6.0.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (121 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=0.8.1->pytorch-lightning==1.2.9)
#   Using cached yarl-1.9.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (31 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=0.8.1->pytorch-lightning==1.2.9)
#   Using cached frozenlist-1.4.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=0.8.1->pytorch-lightning==1.2.9)
#   Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting async-timeout<5.0,>=4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=0.8.1->pytorch-lightning==1.2.9)
#   Using cached async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.9) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.9) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.9) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.9) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.9) (7.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from requests->fsspec[http]>=0.8.1->pytorch-lightning==1.2.9) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from requests->fsspec[http]>=0.8.1->pytorch-lightning==1.2.9) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from requests->fsspec[http]>=0.8.1->pytorch-lightning==1.2.9) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from requests->fsspec[http]>=0.8.1->pytorch-lightning==1.2.9) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from werkzeug>=1.0.1->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.9) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from sympy->torch>=1.4->pytorch-lightning==1.2.9) (1.3.0)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.9) (3.17.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.9) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.9) (3.2.2)
# Using cached aiohttp-3.9.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
# Using cached async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Using cached attrs-23.2.0-py3-none-any.whl (60 kB)
# Using cached frozenlist-1.4.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (240 kB)
# Using cached yarl-1.9.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (308 kB)
# Installing collected packages: multidict, future, frozenlist, attrs, async-timeout, yarl, aiosignal, torchmetrics, aiohttp, pytorch-lightning
# Successfully installed aiohttp-3.9.1 aiosignal-1.3.1 async-timeout-4.0.3 attrs-23.2.0 frozenlist-1.4.1 future-0.18.3 multidict-6.0.4 pytorch-lightning-1.2.9 torchmetrics-0.2.0 yarl-1.9.4
# Collecting tabulate
#   Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Installing collected packages: tabulate
# Successfully installed tabulate-0.9.0
# Collecting kornia==0.5.0
#   Using cached kornia-0.5.0-py2.py3-none-any.whl (271 kB)
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from kornia==0.5.0) (1.23.0)
# Requirement already satisfied: torch>=1.6.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from kornia==0.5.0) (2.1.2+cu118)
# Requirement already satisfied: filelock in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch>=1.6.0->kornia==0.5.0) (3.13.1)
# Requirement already satisfied: typing-extensions in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch>=1.6.0->kornia==0.5.0) (4.5.0)
# Requirement already satisfied: sympy in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch>=1.6.0->kornia==0.5.0) (1.12)
# Requirement already satisfied: networkx in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch>=1.6.0->kornia==0.5.0) (3.1)
# Requirement already satisfied: jinja2 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch>=1.6.0->kornia==0.5.0) (3.1.3)
# Requirement already satisfied: fsspec in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch>=1.6.0->kornia==0.5.0) (2023.12.2)
# Requirement already satisfied: triton==2.1.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch>=1.6.0->kornia==0.5.0) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from jinja2->torch>=1.6.0->kornia==0.5.0) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from sympy->torch>=1.6.0->kornia==0.5.0) (1.3.0)
# Installing collected packages: kornia
# Successfully installed kornia-0.5.0
# Collecting webdataset
#   Using cached webdataset-0.2.86-py3-none-any.whl.metadata (29 kB)
# Collecting braceexpand (from webdataset)
#   Using cached braceexpand-0.1.7-py2.py3-none-any.whl (5.9 kB)
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from webdataset) (1.23.0)
# Requirement already satisfied: pyyaml in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from webdataset) (6.0.1)
# Using cached webdataset-0.2.86-py3-none-any.whl (70 kB)
# Installing collected packages: braceexpand, webdataset
# Successfully installed braceexpand-0.1.7 webdataset-0.2.86
# Requirement already satisfied: packaging in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (23.2)
# Requirement already satisfied: omegaconf==2.1.2 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (2.1.2)
# Requirement already satisfied: antlr4-python3-runtime==4.8 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from omegaconf==2.1.2) (4.8)
# Requirement already satisfied: PyYAML>=5.1.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from omegaconf==2.1.2) (6.0.1)
# Collecting torchvision
#   Using cached torchvision-0.16.2-cp38-cp38-manylinux1_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torchvision) (1.23.0)
# Requirement already satisfied: requests in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torchvision) (2.31.0)
# Requirement already satisfied: torch==2.1.2 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torchvision) (2.1.2+cu118)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torchvision) (10.2.0)
# Requirement already satisfied: filelock in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch==2.1.2->torchvision) (3.13.1)
# Requirement already satisfied: typing-extensions in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch==2.1.2->torchvision) (4.5.0)
# Requirement already satisfied: sympy in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch==2.1.2->torchvision) (1.12)
# Requirement already satisfied: networkx in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch==2.1.2->torchvision) (3.1)
# Requirement already satisfied: jinja2 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch==2.1.2->torchvision) (3.1.3)
# Requirement already satisfied: fsspec in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch==2.1.2->torchvision) (2023.12.2)
# Requirement already satisfied: triton==2.1.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from torch==2.1.2->torchvision) (2.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from requests->torchvision) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from requests->torchvision) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from requests->torchvision) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from requests->torchvision) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from jinja2->torch==2.1.2->torchvision) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from sympy->torch==2.1.2->torchvision) (1.3.0)
# Using cached torchvision-0.16.2-cp38-cp38-manylinux1_x86_64.whl (6.8 MB)
# Installing collected packages: torchvision
# Successfully installed torchvision-0.16.2
# Collecting conda-pack
#   Using cached conda_pack-0.7.1-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/lama_env/lib/python3.8/site-packages (from conda-pack) (69.0.3)
# Using cached conda_pack-0.7.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: conda-pack
# Successfully installed conda-pack-0.7.1
# Collecting packages...
# Packing environment at '/home/ec2-user/anaconda3/envs/lama_env' to 'lama_env.tar.gz'
# [########################################] | 100% Completed |  3min 38.7s

# %% [markdown]
# ### Extend SageMaker Managed Triton Container
#
# When we host these models on SageMaker MME. When invoked, model files will be loaded from S3 onto the instance. Due the large size of our models and model packages (SAM: 2.4GB + conda pack: 2.52 GB, LaMa: 0.38 GB + conda pack: 3.35GB), we are going to pre-load these files into the container. This will reduce model loading time and improve user experience during cold start.

# %%
# account mapping for SageMaker Triton Image
account_id_map = {
    "us-east-1": "785573368785",
    "us-east-2": "007439368137",
    "us-west-1": "710691900526",
    "us-west-2": "301217895009",
    "eu-west-1": "802834080501",
    "eu-west-2": "205493899709",
    "eu-west-3": "254080097072",
    "eu-north-1": "601324751636",
    "eu-south-1": "966458181534",
    "eu-central-1": "746233611703",
    "ap-east-1": "110948597952",
    "ap-south-1": "763008648453",
    "ap-northeast-1": "941853720454",
    "ap-northeast-2": "151534178276",
    "ap-southeast-1": "324986816169",
    "ap-southeast-2": "355873309152",
    "cn-northwest-1": "474822919863",
    "cn-north-1": "472730292857",
    "sa-east-1": "756306329178",
    "ca-central-1": "464438896020",
    "me-south-1": "836785723513",
    "af-south-1": "774647643957",
}



region = boto3.Session().region_name
if region not in account_id_map.keys():
    raise ("UNSUPPORTED REGION")

base = "amazonaws.com.cn" if region.startswith("cn-") else "amazonaws.com"
mme_triton_image_uri = (
    "{account_id}.dkr.ecr.{region}.{base}/sagemaker-tritonserver:22.12-py3".format(
        account_id=account_id_map[region], region=region, base=base
    )
)
triton_account_id = account_id_map[region]
mme_triton_image_uri
# Out:
# '301217895009.dkr.ecr.us-west-2.amazonaws.com/sagemaker-tritonserver:22.12-py3'

# %% [markdown]
# Preview the docker file

# %%
# !cat docker/Dockerfile
# Out:
# ARG BASE_IMAGE
#
# FROM $BASE_IMAGE
#
# #Install any additional libraries
# RUN echo "Adding conda package to Docker image"
# RUN mkdir -p /home/condpackenv/
# RUN mkdir -p /home/models/
#
# # Copy conda env
# COPY sam_env.tar.gz /home/condpackenv/sam_env.tar.gz
# COPY lama_env.tar.gz /home/condpackenv/lama_env.tar.gz
#
# COPY sam_vit_h_4b8939.pth.tar.gz /temp/
# COPY big-lama.tar.gz /temp/
#
# # Install tar
# RUN apt-get update && apt-get install -y tar
# # RUN apt-get update && apt-get install ffmpeg libsm6 libxext6  -y
#
# # Untar the file
# RUN tar -xzf /temp/sam_vit_h_4b8939.pth.tar.gz -C /home/models/
# RUN tar -xzf /temp/big-lama.tar.gz -C /home/models/
#
# RUN rm /temp/sam_vit_h_4b8939.pth.tar.gz
# RUN rm /temp/big-lama.tar.gz

# %% [markdown]
# ### Build & push the new image to ECR

# %%
# New container image name
new_image_name = 'sagemaker-tritonserver-sam-lama'

# %%
# %%capture build_output
# !cd docker && bash build_and_push.sh "$new_image_name" "latest" "$mme_triton_image_uri" "$region" "$account" "$triton_account_id"

# %%
if 'Error response from daemon' in str(build_output):
    print(build_output)
    raise SystemExit('\n\n!!There was an error with the container build!!')
else:
    extended_triton_image_uri = str(build_output).strip().split('\n')[-1]
    
print(f"New image URI from ECR: {extended_triton_image_uri}")
# Out:
# New image URI from ECR: 376678947624.dkr.ecr.us-west-2.amazonaws.com/sagemaker-tritonserver-sam-lama:latest

# %%
# %store extended_triton_image_uri
# Out:
# Stored 'extended_triton_image_uri' (str)
